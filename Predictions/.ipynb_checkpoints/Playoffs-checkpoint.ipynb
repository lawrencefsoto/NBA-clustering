# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from collections import Counter

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

pd.set_option('display.max_columns', 70)
pd.set_option('display.max_rows', 700) # want to see more rows and columns

# %% [markdown]
# ## Reading In My Data

# %%
pg = pd.read_csv('../Positional clustering 17-18/pg_cluster_17_18')
sg = pd.read_csv('../Positional clustering 17-18/sg_cluster_17_18')
sf = pd.read_csv('../Positional clustering 17-18/sf_cluster_17_18')
pf = pd.read_csv('../Positional clustering 17-18/pf_cluster_17_18')
c = pd.read_csv('../Positional clustering 17-18/c_cluster_17_18')

# %% [markdown]
# ## Cleaning Data apply some engineering

# %% [markdown]
# ### PG

# %%
pg.head() # sanity check
# Out:
#               Name   2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  \
# 0    D.J. Augustin  3.6  0.485   7.5  3.2  0.419  7.6   8.0  24.4   30  0.0
# 1       Lonzo Ball  3.0  0.420   7.2  2.4  0.305  7.9  10.1  29.2   20  1.2
# 2       J.J. Barea  5.9  0.499  11.8  3.6  0.367  9.8  13.6  45.1   33  0.1
# 3     Eric Bledsoe  7.4  0.545  13.5  2.7  0.347  7.7   7.9  25.7   28  0.9
# 4  Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6   5.3  16.3   25  0.5
#
#    BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT    FT%  FTA   G  \
# 0   0.0 -0.9  -2.5  3.6   8.2   113   6.8  0.452  15.0  4.6  0.868  5.3  75
# 1   2.0  1.7   2.5  7.8  17.3   106   5.5  0.360  15.2  0.9  0.451  1.9  52
# 2   0.2  0.1  -2.3  5.8  13.4   112   9.5  0.439  21.6  2.5  0.784  3.2  69
# 3   1.5  2.1  -0.3  5.0  11.7   108  10.0  0.473  21.2  5.4  0.795  6.8  74
# 4   0.8 -1.3  -1.9  4.6  10.8   113   8.5  0.485  17.5  2.6  0.882  3.0  48
#
# ...

# %%
## dummy out the position
pg_dummies = pd.get_dummies(pg['pg_cluster'])
pg_dummies.head()
# Out:
#    0  1  2
# 0  0  1  0
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  1  0

# %%
## combining dummy and pg data
pg_concat = pd.concat([pg_dummies, pg], axis=1)
pg_concat.head()
# Out:
#    0  1  2             Name   2P    2P%   2PA   3P    3P%  3PA   AST  AST%  \
# 0  0  1  0    D.J. Augustin  3.6  0.485   7.5  3.2  0.419  7.6   8.0  24.4
# 1  1  0  0       Lonzo Ball  3.0  0.420   7.2  2.4  0.305  7.9  10.1  29.2
# 2  0  0  1       J.J. Barea  5.9  0.499  11.8  3.6  0.367  9.8  13.6  45.1
# 3  0  0  1     Eric Bledsoe  7.4  0.545  13.5  2.7  0.347  7.7   7.9  25.7
# 4  0  1  0  Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6   5.3  16.3
#
#    Age  BLK  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT    FT%  \
# 0   30  0.0   0.0 -0.9  -2.5  3.6   8.2   113   6.8  0.452  15.0  4.6  0.868
# 1   20  1.2   2.0  1.7   2.5  7.8  17.3   106   5.5  0.360  15.2  0.9  0.451
# 2   33  0.1   0.2  0.1  -2.3  5.8  13.4   112   9.5  0.439  21.6  2.5  0.784
# 3   28  0.9   1.5  2.1  -0.3  5.0  11.7   108  10.0  0.473  21.2  5.4  0.795
# 4   25  0.5   0.8 -1.3  -1.9  4.6  10.8   113   8.5  0.485  17.5  2.6  0.882
#
# ...

# %%
# setting index to Name, renaming dummies so I know what's what, dropping original pg_cluster after dummy.

pg_concat.set_index('Name', inplace=True)
pg_concat.rename(index=str, columns={0: 'pg_cluster_0', 1: 'pg_cluster_1', 2: 'pg_cluster_2'}, inplace=True)
pg_concat.drop(columns =['pg_cluster'], inplace = True)

# sorting the columns for pg. important to sort columns if you want to pickle your model for another use.
pg_concat = pg_concat.reindex(sorted(pg_concat.columns), axis=1)
pg_concat.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  \
# Name
# D.J. Augustin    3.6  0.485   7.5  3.2  0.419  7.6   8.0  24.4   30  0.0
# Lonzo Ball       3.0  0.420   7.2  2.4  0.305  7.9  10.1  29.2   20  1.2
# J.J. Barea       5.9  0.499  11.8  3.6  0.367  9.8  13.6  45.1   33  0.1
# Eric Bledsoe     7.4  0.545  13.5  2.7  0.347  7.7   7.9  25.7   28  0.9
# Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6   5.3  16.3   25  0.5
#
#                  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# D.J. Augustin     0.0 -0.9  -2.5  3.6   8.2   113   6.8  0.452  15.0  4.6
# Lonzo Ball        2.0  1.7   2.5  7.8  17.3   106   5.5  0.360  15.2  0.9
# J.J. Barea        0.2  0.1  -2.3  5.8  13.4   112   9.5  0.439  21.6  2.5
# Eric Bledsoe      1.5  2.1  -0.3  5.0  11.7   108  10.0  0.473  21.2  5.4
# Malcolm Brogdon   0.8 -1.3  -1.9  4.6  10.8   113   8.5  0.485  17.5  2.6
#
# ...

# %% [markdown]
# ### SG

# %%
sg.head()# sanity check
# Out:
#             Name   2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  \
# 0   Alex Abrines  1.4  0.443   3.1  3.7  0.380  9.7  1.2   3.4   24  0.4
# 1  Arron Afflalo  2.7  0.413   6.6  1.9  0.386  5.0  2.2   6.2   32  0.6
# 2   Dwayne Bacon  4.2  0.409  10.2  0.8  0.256  2.9  2.6   7.5   22  0.1
# 3    Will Barton  5.7  0.510  11.2  2.9  0.370  7.8  6.1  18.5   27  1.0
# 4  Nicolas Batum  4.4  0.473   9.3  2.3  0.336  6.7  8.6  26.2   29  0.6
#
#    BLK%  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT    FT%  FTA   G  \
# 0   0.6 -2.2  -1.7  3.9   8.9   110  5.0  0.395  12.7  1.7  0.848  2.0  75
# 1   1.1 -5.8  -1.8  4.5  10.1   115  4.7  0.401  11.6  1.6  0.846  1.9  53
# 2   0.2 -5.7  -0.3  8.2  18.5   111  4.9  0.375  13.1  1.4  0.800  1.7  53
# 3   1.6  1.0  -0.6  6.3  14.2   112  8.6  0.452  19.0  3.4  0.805  4.2  81
# 4   1.0  1.4   0.5  6.1  13.8   110  6.6  0.415  16.0  2.7  0.831  3.2  64
#
# ...

# %%
sg_dummies = pd.get_dummies(sg['sg_cluster'])
sg_concat = pd.concat([sg_dummies, sg], axis=1)
sg_concat.set_index('Name', inplace=True)
sg_concat.rename(index=str, columns={0: 'sg_cluster_0', 1: 'sg_cluster_1'}, inplace=True)
sg_concat.drop(columns=['sg_cluster'], inplace=True)
sg_concat = sg_concat.reindex(sorted(sg_concat.columns), axis=1)

sg_concat.head()
# Out:
#                 2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Alex Abrines   1.4  0.443   3.1  3.7  0.380  9.7  1.2   3.4   24  0.4   0.6
# Arron Afflalo  2.7  0.413   6.6  1.9  0.386  5.0  2.2   6.2   32  0.6   1.1
# Dwayne Bacon   4.2  0.409  10.2  0.8  0.256  2.9  2.6   7.5   22  0.1   0.2
# Will Barton    5.7  0.510  11.2  2.9  0.370  7.8  6.1  18.5   27  1.0   1.6
# Nicolas Batum  4.4  0.473   9.3  2.3  0.336  6.7  8.6  26.2   29  0.6   1.0
#
#                BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT    FT%  FTA  \
# Name
# Alex Abrines  -2.2  -1.7  3.9   8.9   110  5.0  0.395  12.7  1.7  0.848  2.0
# Arron Afflalo -5.8  -1.8  4.5  10.1   115  4.7  0.401  11.6  1.6  0.846  1.9
# Dwayne Bacon  -5.7  -0.3  8.2  18.5   111  4.9  0.375  13.1  1.4  0.800  1.7
# Will Barton    1.0  -0.6  6.3  14.2   112  8.6  0.452  19.0  3.4  0.805  4.2
# Nicolas Batum  1.4   0.5  6.1  13.8   110  6.6  0.415  16.0  2.7  0.831  3.2
#
# ...

# %% [markdown]
# ### SF

# %%
sf_dummies = pd.get_dummies(sf['sf_cluster'])
sf_concat = pd.concat([sf_dummies, sf], axis=1)
sf_concat.rename(index=str, columns={0: 'sf_cluster_0', 1: 'sf_cluster_1', 2:'sf_cluster_2'}, inplace=True)
sf_concat.drop(columns=['sf_cluster'], inplace=True)
sf_concat.set_index('Name', inplace=True)
sf_concat = sf_concat.reindex(sorted(sf_concat.columns), axis=1)
sf_concat.head()
# Out:
#                    2P    2P%  2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Kyle Anderson     5.4  0.556  9.7  0.5  0.333   1.5  5.2  14.7   24  1.5
# OG Anunoby        3.0  0.604  5.0  2.4  0.371   6.6  1.8   5.0   20  0.5
# Trevor Ariza      2.1  0.519  4.1  3.7  0.368  10.0  2.3   6.8   32  0.3
# Luke Babbitt      2.1  0.525  4.1  4.1  0.385  10.7  2.1   6.5   28  0.5
# Bojan Bogdanovic  5.1  0.534  9.5  3.1  0.402   7.8  2.4   7.1   28  0.2
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT  \
# Name
# Kyle Anderson      2.5  4.1   4.3  8.0  17.6   101  5.9  0.527  11.2  2.7
# OG Anunoby         0.8  0.6   0.4  4.7  10.4   108  5.4  0.471  11.5  1.3
# Trevor Ariza       0.5  1.5   0.7  5.7  12.9   107  5.8  0.412  14.1  1.6
# Luke Babbitt       0.8 -3.2  -2.2  6.1  13.9   113  6.3  0.423  14.8  1.2
# Bojan Bogdanovic   0.3 -0.7  -1.9  4.9  10.9   112  8.2  0.474  17.3  3.6
#
# ...

# %% [markdown]
# ### PF

# %%
pf_dummies = pd.get_dummies(pf['pf_cluster'])
pf_concat = pd.concat([pf_dummies, pf], axis=1)
pf_concat.set_index('Name', inplace=True)
pf_concat.rename(index=str, columns={0: 'pf_cluster_0', 1: 'pf_cluster_1', 2:'pf_cluster_2', 3:'pf_cluster_3',
                                     4:'pf_cluster_4'}, inplace=True)
pf_concat.drop(columns=['pf_cluster'], inplace=True)
pf_concat = pf_concat.reindex(sorted(pf_concat.columns), axis=1)
pf_concat.head()
# Out:
#                          2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  \
# Name
# Quincy Acy              1.0  0.384   2.6  3.6  0.349  10.4  2.0   6.0   27
# Al-Farouq Aminu         2.5  0.432   5.8  3.0  0.369   8.1  2.0   5.8   27
# Ryan Anderson           2.2  0.539   4.0  3.7  0.386   9.7  1.7   5.1   29
# Giannis Antetokounmpo  12.6  0.554  22.8  0.8  0.307   2.5  6.5  23.7   23
# Carmelo Anthony         6.0  0.437  13.8  3.4  0.357   9.4  2.0   6.5   33
#
#                        BLK  BLK%  BPM  DBPM   DRB  DRB%  DRtg    FG    FG%  \
# Name
# Quincy Acy             1.0   1.6 -2.2  -0.2   7.8  17.0   110   4.6  0.356
# Al-Farouq Aminu        1.0   1.6  1.1   1.9  10.3  22.3   104   5.5  0.395
# Ryan Anderson          0.6   1.0  0.2  -0.8   6.8  15.4   109   5.9  0.431
# Giannis Antetokounmpo  1.9   3.3  5.8   1.9  10.8  25.3   106  13.4  0.529
# Carmelo Anthony        1.0   1.8 -3.8  -1.9   7.7  17.7   109   9.4  0.404
#
# ...

# %% [markdown]
# ### C

# %%
c_dummies = pd.get_dummies(c['c_cluster'])
c_concat = pd.concat([c_dummies, c], axis=1)
c_concat.set_index('Name', inplace=True)
c_concat.rename(index=str, columns={0: 'c_cluster_0', 1: 'c_cluster_1', 2:'c_cluster_2'}, inplace=True)
c_concat.drop(columns=['c_cluster'], inplace=True)
c_concat = c_concat.reindex(sorted(c_concat.columns), axis=1)
c_concat.head()
# Out:
#                      2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  \
# Name
# Steven Adams        8.9  0.631  14.2  0.0  0.000  0.0  1.8   5.5   24  1.6
# Bam Adebayo         6.4  0.523  12.2  0.0  0.000  0.3  3.7  11.0   20  1.5
# LaMarcus Aldridge  13.3  0.526  25.3  0.5  0.293  1.9  3.1  11.3   32  1.8
# Jarrett Allen       7.7  0.599  12.9  0.2  0.333  0.5  1.7   5.4   19  3.0
# Aron Baynes         7.0  0.487  14.3  0.1  0.143  0.7  3.1   9.6   31  1.7
#
#                    BLK%  BPM  DBPM   DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Steven Adams        2.8  3.3   1.1   6.0  13.9   107   8.9  0.629  14.2  3.2
# Bam Adebayo         2.5  0.2   1.8   9.7  21.6   105   6.4  0.512  12.5  4.7
# LaMarcus Aldridge   3.0  3.3   0.3   7.8  17.3   105  13.8  0.510  27.1  6.7
# Jarrett Allen       4.6  0.2   1.4   8.2  18.2   108   7.9  0.589  13.4  3.8
# Aron Baynes         2.9 -1.7   2.1  10.2  22.1   103   7.1  0.471  15.0  2.0
#
# ...

# %% [markdown]
# ## Combining all the data together

# %%
test = [pg_concat, sg_concat, sf_concat,pf_concat,c_concat]
season_17_18_cluster = pd.concat(test, sort=True)
season_17_18_cluster.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  \
# Name
# D.J. Augustin    3.6  0.485   7.5  3.2  0.419  7.6   8.0  24.4   30  0.0
# Lonzo Ball       3.0  0.420   7.2  2.4  0.305  7.9  10.1  29.2   20  1.2
# J.J. Barea       5.9  0.499  11.8  3.6  0.367  9.8  13.6  45.1   33  0.1
# Eric Bledsoe     7.4  0.545  13.5  2.7  0.347  7.7   7.9  25.7   28  0.9
# Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6   5.3  16.3   25  0.5
#
#                  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# D.J. Augustin     0.0 -0.9  -2.5  3.6   8.2   113   6.8  0.452  15.0  4.6
# Lonzo Ball        2.0  1.7   2.5  7.8  17.3   106   5.5  0.360  15.2  0.9
# J.J. Barea        0.2  0.1  -2.3  5.8  13.4   112   9.5  0.439  21.6  2.5
# Eric Bledsoe      1.5  2.1  -0.3  5.0  11.7   108  10.0  0.473  21.2  5.4
# Malcolm Brogdon   0.8 -1.3  -1.9  4.6  10.8   113   8.5  0.485  17.5  2.6
#
# ...

# %%
season_17_18_cluster.isnull().sum() ## checking null values
# Out:
# 2P                0
# 2P%               0
# 2PA               0
# 3P                0
# 3P%               0
# 3PA               0
# AST               0
# AST%              0
# Age               0
# BLK               0
# BLK%              0
# BPM               0
# DBPM              0
# DRB               0
# DRB%              0
# DRtg              0
# FG                0
# FG%               0
# FGA               0
# FT                0
# FT%               0
# FTA               0
# G                 0
# GS                0
# MP                0
# OBPM              0
# ORB               0
# ORB%              0
# ORtg              0
# PER               0
# PF                0
# PTS               0
# Pos               0
# STL               0
# STL%              0
# TOV               0
# TOV%              0
# TRB               0
# TRB%              0
# TS%               0
# Tm                0
# USG%              0
# VORP              0
# c_cluster_0     258
# c_cluster_1     258
# ...

# %%
## Filling null values and just sorting again just to double check
season_17_18_cluster.fillna(0, inplace=True)
season_17_18_cluster = season_17_18_cluster.reindex(sorted(season_17_18_cluster.columns), axis=1)

# %%
season_17_18_cluster.head() #sanity check
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  \
# Name
# D.J. Augustin    3.6  0.485   7.5  3.2  0.419  7.6   8.0  24.4   30  0.0
# Lonzo Ball       3.0  0.420   7.2  2.4  0.305  7.9  10.1  29.2   20  1.2
# J.J. Barea       5.9  0.499  11.8  3.6  0.367  9.8  13.6  45.1   33  0.1
# Eric Bledsoe     7.4  0.545  13.5  2.7  0.347  7.7   7.9  25.7   28  0.9
# Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6   5.3  16.3   25  0.5
#
#                  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# D.J. Augustin     0.0 -0.9  -2.5  3.6   8.2   113   6.8  0.452  15.0  4.6
# Lonzo Ball        2.0  1.7   2.5  7.8  17.3   106   5.5  0.360  15.2  0.9
# J.J. Barea        0.2  0.1  -2.3  5.8  13.4   112   9.5  0.439  21.6  2.5
# Eric Bledsoe      1.5  2.1  -0.3  5.0  11.7   108  10.0  0.473  21.2  5.4
# Malcolm Brogdon   0.8 -1.3  -1.9  4.6  10.8   113   8.5  0.485  17.5  2.6
#
# ...

# %%
season_17_18_cluster.to_csv('./17_18_cluster')

# %% [markdown]
# ## Picking top 9 players from each team

# %% [markdown]
# ### TOR

# %%
TOR_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='TOR']
TOR_17_18.head() # I did .head() so it'll be easier to read but I needed to see the whole dataframe to determine
# which players to keep or which players I needed to add or delete.
# Out:
#                  2P    2P%   2PA   3P    3P%   3PA   AST  AST%  Age  BLK  \
# Name
# Kyle Lowry      3.2  0.474   6.8  4.7  0.399  11.7  10.5  30.9   31  0.4
# Fred VanVleet   4.0  0.437   9.2  3.5  0.414   8.5   7.9  22.8   23  0.6
# Delon Wright    5.0  0.520   9.6  1.9  0.366   5.3   6.9  19.6   25  1.1
# DeMar DeRozan  10.1  0.494  20.5  1.6  0.310   5.2   7.6  25.0   28  0.4
# Norman Powell   4.5  0.516   8.7  2.5  0.285   8.6   4.1  11.8   24  0.7
#
#                BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Kyle Lowry      0.6  5.9   0.5  7.2  16.1   107   7.9  0.427  18.5  4.4
# Fred VanVleet   1.0  1.9   0.1  5.2  11.5   106   7.5  0.426  17.7  2.7
# Delon Wright    1.8  2.8   1.6  5.3  11.7   105   6.9  0.465  14.9  3.3
# DeMar DeRozan   0.6  1.8  -0.9  4.7  10.4   109  11.7  0.456  25.7  8.4
# Norman Powell   1.2 -2.8  -0.4  4.9  10.9   107   7.0  0.401  17.4  1.5
#
#                  FT%   FTA   G  GS      MP  OBPM  ORB  ORB%  ORtg   PER   PF  \
# ...

# %%
## going to keep top 9 players from each team

# %%
TOR_17_18.drop(['Norman Powell', 'Lucas Nogueira', 'C.J. Miles'], inplace=True)
TOR_17_18.drop(columns=['Pos'], inplace=True)
TOR_17_18_sum = pd.DataFrame(TOR_17_18.sum(axis=0))
TOR_17_18_sum.loc['Tm', 0]= 'TOR17-18'
TOR_17_18_sum = TOR_17_18_sum.T.set_index('Tm')
TOR_17_18_sum
# Out:
# /Users/lawrencefrancosoto/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#             2P    2P%    2PA    3P    3P%   3PA AST   AST%  Age   BLK BLK%  \
# Tm
# TOR17-18  56.8  4.947  103.2  18.4  3.345  50.4  45  134.1  225  11.7   19
#
#            BPM DBPM   DRB   DRB% DRtg  FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# TOR17-18  19.7  8.2  65.9  146.4  952  75  4.463  153.4  30.7  6.787  39.4
#
#             G   GS     MP  OBPM   ORB  ORB%  ORtg    PER  PF    PTS   STL  \
# Tm
# TOR17-18  693  382  16678  11.7  20.8  48.6  1042  152.1  40  199.6  14.2
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# TOR17-18  14.2  23.5  110.4  86.6  98.4  5.283  172.6   18           1
#
# ...

# %%
## need to divide certain percentages by 9 will do that after I add all the teams.
### Note percentages need to divide by 9 for 9 players

# %% [markdown]
# ### Celtics

# %%
BOS_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='BOS']
BOS_17_18.head()
# Out:
#                2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Kyrie Irving  9.5  0.541  17.6  4.3  0.408  10.5  7.9  30.7   25  0.4   0.7
# Shane Larkin  3.4  0.398   8.6  2.0  0.360   5.5  6.3  18.5   25  0.1   0.3
# Terry Rozier  3.9  0.410   9.6  3.7  0.381   9.7  5.6  17.5   23  0.5   0.8
# Jaylen Brown  5.9  0.507  11.5  2.8  0.395   7.1  2.6   8.5   21  0.6   1.0
# Marcus Smart  3.5  0.429   8.2  2.3  0.301   7.7  8.0  23.7   23  0.7   1.2
#
#               BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT    FT%  FTA  \
# Name
# Kyrie Irving  6.2  -0.7  5.0  10.8   106  13.8  0.491  28.1  6.0  0.889  6.8
# Shane Larkin -2.1   0.2  5.0  10.7   106   5.4  0.384  14.1  2.1  0.865  2.4
# Terry Rozier  1.8   1.0  7.6  16.3   104   7.6  0.395  19.3  2.8  0.772  3.6
# Jaylen Brown -0.2   0.4  6.5  14.0   105   8.7  0.465  18.6  3.5  0.644  5.4
# Marcus Smart -0.5   1.1  4.5   9.8   104   5.9  0.367  15.9  3.0  0.729  4.1
#
# ...

# %%
BOS_17_18.drop(['Shane Larkin', 'Abdel Nader','Daniel Theis'], inplace=True)
BOS_17_18.drop(columns=['Pos'], inplace=True)
BOS_17_18_sum = pd.DataFrame(BOS_17_18.sum(axis=0))
BOS_17_18_sum.loc['Tm', 0]= 'BOS17-18'
BOS_17_18_sum = BOS_17_18_sum.T.set_index('Tm')
BOS_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# BOS17-18  48.9  4.244  100.7  22.2  3.179  59.2  40.6  132.4  224  7.4  12.5
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# BOS17-18  5.4  7.8  64.3  138.8  940  71.1  3.928  159.8  29.2  6.814  37.5
#
#             G   GS     MP OBPM ORB  ORB% ORtg    PER    PF    PTS   STL  STL%  \
# Tm
# BOS17-18  624  397  16562 -2.3  16  35.6  961  128.6  35.2  193.4  12.8  12.8
#
#            TOV   TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# BOS17-18  23.6  107.9  80.3  87.8  4.848  178.9  12.7           0           2
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# BOS17-18           0            1            1            0            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# BOS17-18            0            0            1            1            0
#
# ...

# %% [markdown]
# ### Phili

# %%
PHI_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='PHI']
PHI_17_18.head()
# Out:
#                           2P    2P%   2PA   3P    3P%   3PA   AST  AST%  Age  \
# Name
# T.J. McConnell           5.2  0.510  10.1  0.8  0.435   1.7   8.5  24.5   25
# Ben Simmons              9.6  0.551  17.4  0.0  0.000   0.2  11.6  37.4   21
# J.J. Redick              4.8  0.504   9.5  4.4  0.420  10.5   4.8  15.1   33
# Robert Covington         2.7  0.497   5.4  3.9  0.369  10.4   3.0   8.7   27
# Timothe Luwawu-Cabarrot  2.8  0.431   6.5  3.2  0.335   9.4   3.2   9.3   22
#
#                          BLK  BLK%  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%  \
# Name
# T.J. McConnell           0.4   0.6 -0.7   1.1  5.3  11.5   105  5.9  0.499
# Ben Simmons              1.2   2.1  4.6   3.6  9.0  19.5   102  9.6  0.545
# J.J. Redick              0.1   0.2  0.0  -2.6  3.8   8.3   110  9.2  0.460
# Robert Covington         1.4   2.4  2.5   2.1  7.2  15.5   103  6.6  0.413
# Timothe Luwawu-Cabarrot  0.3   0.5 -4.7  -2.4  3.5   7.5   110  6.0  0.375
#
# ...

# %%
PHI_17_18.drop(columns=['Pos'], inplace=True)
PHI_17_18_sum = pd.DataFrame(PHI_17_18.sum(axis=0))
PHI_17_18_sum.loc['Tm', 0]= 'PHI17-18'
PHI_17_18_sum = PHI_17_18_sum.T.set_index('Tm')
PHI_17_18_sum
# Out:
#             2P    2P%    2PA  3P    3P%   3PA AST   AST%  Age   BLK  BLK%  \
# Tm
# PHI17-18  55.1  4.715  103.2  18  2.702  49.2  49  152.2  228  10.3  17.6
#
#            BPM DBPM   DRB   DRB% DRtg  FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# PHI17-18  10.3  9.1  68.6  148.1  943  73  4.326  152.6  30.9  6.807  41.3
#
#             G   GS     MP OBPM   ORB  ORB%  ORtg    PER  PF    PTS   STL  \
# Tm
# PHI17-18  622  395  16032  1.2  21.2  49.4  1008  139.2  43  194.4  14.4
#
#           STL% TOV   TOV%   TRB   TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# PHI17-18  14.4  28  126.2  89.9  100.5  5.105  176.2   15           2
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# PHI17-18           0           1            0            1            0
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# PHI17-18            0            0            1            1            0
#
# ...

# %% [markdown]
# ## NY

# %%
NYK_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='NYK']
NYK_17_18
# Out:
#                       2P    2P%   2PA   3P    3P%   3PA   AST  AST%  Age  BLK  \
# Name
# Jarrett Jack         5.3  0.459  11.4  0.8  0.291   2.8  11.1  31.3   34  0.1
# Frank Ntilikina      3.8  0.385  10.0  1.5  0.318   4.6   7.3  20.0   19  0.5
# Damyean Dotson       5.2  0.538   9.7  2.3  0.324   7.1   3.2   9.5   23  0.2
# Tim Hardaway         6.0  0.516  11.7  3.4  0.317  10.8   4.1  12.7   25  0.3
# Courtney Lee         4.9  0.482  10.2  2.4  0.406   6.0   3.9  11.3   32  0.4
# Michael Beasley     11.2  0.520  21.6  1.0  0.395   2.6   3.7  12.5   29  1.3
# Kristaps Porzingis   9.6  0.454  21.1  2.9  0.395   7.3   1.8   6.2   22  3.7
# Lance Thomas         1.9  0.364   5.2  1.8  0.403   4.5   1.6   4.2   29  0.5
# Enes Kanter         11.4  0.594  19.3  0.0  0.000   0.1   2.8   9.4   25  1.0
# Kyle O'Quinn         7.9  0.599  13.1  0.1  0.235   0.6   5.6  16.8   27  3.5
#
#                     BLK%  BPM  DBPM   DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# ...

# %%
NYK_17_18.drop(['Damyean Dotson'], inplace=True)
NYK_17_18.drop(columns=['Pos'], inplace=True)
NYK_17_18_sum = pd.DataFrame(NYK_17_18.sum(axis=0))
NYK_17_18_sum.loc['Tm', 0]= 'NYK17-18'
NYK_17_18_sum = NYK_17_18_sum.T.set_index('Tm')
NYK_17_18_sum
# Out:
#           2P    2P%    2PA    3P   3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# NYK17-18  62  4.373  123.6  13.9  2.76  39.3  41.9  124.4  242  11.3  19.6
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# NYK17-18 -5.3 -1.4  67.3  150.2  996  76.1  4.169  162.8  29.6  7.319  36.8
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# NYK17-18  616  378  15225 -3.9  21.4  48.1  961  134.4  39.6  195.9  11.9
#
#           STL%   TOV TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# NYK17-18  11.9  27.4  124  88.7  99.4  4.886  181.7  5.6           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# NYK17-18           0           1            1            2            0
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# NYK17-18            0            0            0            2            0
#
# ...

# %% [markdown]
# ## BK

# %%
BRK_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='BRK']
BRK_17_18.head()
# Out:
#                     2P    2P%   2PA   3P    3P%   3PA   AST  AST%  Age  BLK  \
# Name
# Spencer Dinwiddie  3.9  0.452   8.5  3.0  0.326   9.1  11.0  35.0   24  0.5
# D'Angelo Russell   7.4  0.477  15.5  3.5  0.324  10.9   9.8  35.7   21  0.7
# Allen Crabbe       3.0  0.461   6.5  4.4  0.378  11.8   2.6   8.4   25  0.8
# Joe Harris         3.8  0.589   6.5  3.7  0.419   8.8   3.1  10.2   26  0.5
# DeMarre Carroll    4.0  0.457   8.8  3.2  0.371   8.7   3.3  10.5   31  0.7
#
#                    BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Spencer Dinwiddie   0.7  0.2  -1.8  4.6  10.2   112   6.8  0.387  17.6  4.6
# D'Angelo Russell    1.0 -0.4  -1.2  6.3  13.8   111  10.9  0.414  26.4  3.8
# Allen Crabbe        1.2 -0.8  -1.2  6.5  14.4   112   7.4  0.407  18.3  2.5
# Joe Harris          0.8  0.1  -1.2  5.1  11.3   113   7.5  0.491  15.3  2.1
# DeMarre Carroll     1.0  0.2  -0.3  8.3  18.4   110   7.2  0.414  17.5  4.2
#
# ...

# %%
BRK_17_18.drop(columns=['Pos'], inplace=True)
BRK_17_18_sum = pd.DataFrame(BRK_17_18.sum(axis=0))
BRK_17_18_sum.loc['Tm', 0]= 'BRK17-18'
BRK_17_18_sum = BRK_17_18_sum.T.set_index('Tm')
BRK_17_18_sum
# Out:
#             2P   2P% 2PA    3P    3P% 3PA   AST   AST%  Age BLK  BLK%  BPM  \
# Tm
# BRK17-18  45.2  4.39  91  24.1  3.088  68  45.5  151.4  219   9  13.7 -3.6
#
#          DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA    G  \
# Tm
# BRK17-18 -3.6  61.3  135.2  995  69.2  3.965  158.9  32.6  7.088  41.9  635
#
#            GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  STL%  \
# Tm
# BRK17-18  356  16476 -0.1  16.5  35.6  974  127.9  36.9  195.7  11.8  11.8
#
#            TOV   TOV%   TRB TRB%    TS%   USG% VORP c_cluster_0 c_cluster_1  \
# Tm
# BRK17-18  26.7  115.5  77.9   85  5.012  181.9    7           1           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# BRK17-18           0            1            0            0            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# BRK17-18            0            0            1            1            0
#
# ...

# %% [markdown]
# ## Cleveland

# %%
## Adding Jae Crowder to Cleveland, cause he was under TOT instead of CLE
season_17_18_cluster.loc['Jae Crowder', 'Tm'] = 'CLE'

# %%
CLE_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='CLE']
CLE_17_18.head()
# Out:
#                 2P    2P%  2PA   3P    3P%   3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Jose Calderon  2.6  0.545  4.7  2.4  0.464   5.2  6.3  17.4   36  0.1   0.2
# Kyle Korver    1.8  0.537  3.4  5.1  0.436  11.7  2.7   8.0   36  0.8   1.5
# J.R. Smith     2.1  0.453  4.7  3.1  0.375   8.3  3.1   8.6   32  0.2   0.4
# Jae Crowder    3.8  0.488  7.8  2.6  0.323   8.1  2.3   6.9   27  0.5   0.9
# Cedi Osman     4.2  0.586  7.2  2.3  0.368   6.3  3.0   8.7   22  0.2   0.4
#
#                BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT    FT%  FTA  \
# Name
# Jose Calderon -1.9  -2.0  3.8   8.5   115  5.0  0.503   9.9  1.3  0.800  1.6
# Kyle Korver    0.1  -2.0  4.9  10.9   114  6.9  0.459  15.1  2.0  0.889  2.2
# J.R. Smith    -1.7  -1.0  4.5  10.1   114  5.2  0.403  13.0  0.9  0.696  1.2
# Jae Crowder   -1.7  -0.9  5.1  11.5   111  6.4  0.404  15.9  2.9  0.818  3.5
# Cedi Osman    -2.9  -1.5  7.4  16.6   112  6.6  0.484  13.6  1.9  0.565  3.4
#
# ...

# %%
CLE_17_18.drop(columns=['Pos'], inplace=True)
CLE_17_18_sum = pd.DataFrame(CLE_17_18.sum(axis=0))
CLE_17_18_sum.loc['Tm', 0]= 'CLE17-18'
CLE_17_18_sum = CLE_17_18_sum.T.set_index('Tm')
CLE_17_18_sum
# Out:
#             2P    2P%   2PA    3P   3P%   3PA   AST   AST%  Age  BLK BLK%  \
# Tm
# CLE17-18  44.3  4.808  81.3  23.4  3.06  60.6  36.8  116.1  272  5.3  9.5
#
#           BPM DBPM   DRB   DRB%  DRtg    FG    FG%  FGA    FT    FT%   FTA  \
# Tm
# CLE17-18 -1.6 -9.5  64.1  144.2  1010  67.8  4.292  142  29.6  6.791  38.3
#
#             G   GS     MP OBPM   ORB  ORB%  ORtg  PER    PF    PTS STL STL%  \
# Tm
# CLE17-18  623  332  15071    8  16.5  38.1  1031  134  36.4  188.6  12   12
#
#            TOV   TOV%   TRB  TRB%    TS% USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# CLE17-18  21.6  107.7  80.3  92.1  5.322  163  11.3           1           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# CLE17-18           1            0            0            1            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# CLE17-18            1            0            1            0            2
#
# ...

# %% [markdown]
# ## Indiana

# %%
IND_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='IND']
IND_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  \
# Name
# Darren Collison   5.4  0.508  10.7  2.4  0.468  5.1  9.1  26.4   30  0.4
# Cory Joseph       4.3  0.457   9.4  1.5  0.353  4.3  5.9  16.1   26  0.4
# Joe Young         4.9  0.458  10.7  2.2  0.379  5.9  3.5   9.9   25  0.1
# Victor Oladipo    9.4  0.528  17.8  3.2  0.371  8.5  6.3  21.2   25  1.1
# Lance Stephenson  6.4  0.495  12.9  1.8  0.289  6.3  6.3  18.6   27  0.5
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Darren Collison    0.7  2.2  -1.0  3.5   7.8   110   7.8  0.495  15.8  3.1
# Cory Joseph        0.7 -1.2   0.1  5.1  11.4   110   5.8  0.424  13.7  1.6
# Joe Young          0.2 -4.7  -2.3  4.6  10.3   112   7.2  0.430  16.7  2.0
# Victor Oladipo     2.0  4.9   1.3  6.7  15.1   104  12.5  0.477  26.3  5.8
# Lance Stephenson   0.8 -2.1  -0.1  9.8  22.0   108   8.2  0.427  19.2  2.3
#
# ...

# %%
IND_17_18.drop(['T.J. Leaf'], inplace=True) # dropping extra player

# %%
IND_17_18.drop(columns=['Pos'], inplace=True)
IND_17_18_sum = pd.DataFrame(IND_17_18.sum(axis=0))
IND_17_18_sum.loc['Tm', 0]= 'IND17-18'
IND_17_18_sum = IND_17_18_sum.T.set_index('Tm')
IND_17_18_sum
# Out:
#             2P    2P%    2PA    3P   3P%   3PA AST   AST%  Age  BLK  BLK%  \
# Tm
# IND17-18  58.3  4.554  114.4  17.2  3.29  46.7  43  127.5  232  7.5  13.2
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# IND17-18  0.4 -0.2  60.9  136.6  976  75.5  4.207  161.3  28.5  6.839  36.7
#
#             G   GS     MP OBPM   ORB ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# IND17-18  661  406  17905  0.3  16.7   38  985  138.2  35.1  196.5  15.9
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0  \
# Tm
# IND17-18  15.9  24.7  109.2  77.5  87.5  4.973  180.3  11.9           0
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# IND17-18           1           1            0            0            1
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# IND17-18            0            0            0            3            0
#
# ...

# %% [markdown]
# ### Milwaulkee

# %%
season_17_18_cluster.loc['Eric Bledsoe', 'Tm']='MIL'

# %%
MIL_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='MIL']
MIL_17_18.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Eric Bledsoe     7.4  0.545  13.5  2.7  0.347  7.7  7.9  25.7   28  0.9   1.5
# Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6  5.3  16.3   25  0.5   0.8
# Sterling Brown   3.2  0.439   7.3  2.1  0.352  5.8  1.6   4.5   22  0.8   1.4
# Tony Snell       1.9  0.490   3.8  2.6  0.403  6.5  2.4   6.5   26  0.7   1.2
# Jason Terry      1.2  0.487   2.4  2.5  0.348  7.0  3.6   9.7   40  0.8   1.4
#
#                  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT    FT%  \
# Name
# Eric Bledsoe     2.1  -0.3  5.0  11.7   108  10.0  0.473  21.2  5.4  0.795
# Malcolm Brogdon -1.3  -1.9  4.6  10.8   113   8.5  0.485  17.5  2.6  0.882
# Sterling Brown  -4.0  -1.0  7.5  17.5   110   5.3  0.400  13.2  1.3  0.875
# Tony Snell      -1.8  -1.3  3.2   7.5   114   4.5  0.435  10.3  0.9  0.792
# Jason Terry     -2.1  -0.5  2.6   6.2   111   3.6  0.383   9.4  0.5  0.889
#
# ...

# %%
MIL_17_18.drop(columns=['Pos'], inplace=True)
MIL_17_18_sum = pd.DataFrame(MIL_17_18.sum(axis=0))
MIL_17_18_sum.loc['Tm', 0]= 'MIL17-18'
MIL_17_18_sum = MIL_17_18_sum.T.set_index('Tm')
MIL_17_18_sum
# Out:
#             2P    2P%   2PA    3P    3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# MIL17-18  51.3  4.609  97.2  16.5  2.942  46.3  37.6  117.9  237  10.9  18.6
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# MIL17-18 -3.2 -2.5  55.3  129.7  991  67.7  4.154  143.7  29.8  7.146  38.5
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# MIL17-18  609  399  16347 -0.8  14.5  34.4  981  130.3  39.8  181.6  16.9
#
#           STL% TOV   TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0  \
# Tm
# MIL17-18  16.9  22  105.9  69.9  82.1  5.022  165.3  10.5           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# MIL17-18           1           0            0            0            0
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# MIL17-18            0            1            0            1            1
#
# ...

# %% [markdown]
# ### Detroit

# %%
## Blake got traded for Tobias

# %%
season_17_18_cluster.loc['Blake Griffin', 'Tm']= 'DET'

# %%
DET_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='DET']
DET_17_18.head()
# Out:
#                     2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Reggie Jackson     8.1  0.475  16.9  2.2  0.308   7.0  9.9  32.8   27  0.2
# Ish Smith          8.6  0.506  17.1  0.9  0.347   2.5  8.8  28.4   29  0.5
# Langston Galloway  2.9  0.418   7.1  4.3  0.344  12.6  3.4  10.1   26  0.3
# Luke Kennard       4.3  0.463   9.2  2.8  0.415   6.6  4.2  12.7   21  0.4
# Reggie Bullock     4.1  0.536   7.6  3.6  0.445   8.1  2.7   8.4   26  0.4
#
#                    BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Reggie Jackson      0.3 -1.5  -2.3  4.0   9.0   111  10.2  0.426  24.0  4.7
# Ish Smith           0.9 -1.2  -0.6  4.8  10.9   109   9.5  0.486  19.6  2.0
# Langston Galloway   0.5 -1.7  -1.6  4.6  10.3   109   7.3  0.371  19.7  1.9
# Luke Kennard        0.8 -1.5  -0.4  5.3  11.9   109   7.0  0.443  15.9  2.2
# Reggie Bullock      0.7  0.7  -0.7  3.7   8.3   110   7.7  0.489  15.7  1.1
#
# ...

# %%
DET_17_18.drop(['Eric Moreland'], inplace=True)

# %%
DET_17_18.drop(columns=['Pos'], inplace=True)
DET_17_18_sum = pd.DataFrame(DET_17_18.sum(axis=0))
DET_17_18_sum.loc['Tm', 0]= 'DET17-18'
DET_17_18_sum = DET_17_18_sum.T.set_index('Tm')
DET_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# DET17-18  50.5  4.416  102.8  22.9  2.926  61.6  47.3  150.8  234  5.6  10.1
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# DET17-18  3.1 -0.1  58.6  131.9  974  73.2  4.021  164.5  28.8  6.949  38.1
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF  PTS   STL  STL%  \
# Tm
# DET17-18  604  343  15548    3  15.9  34.4  991  134.6  31.1  198  14.2  14.2
#
#          TOV  TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# DET17-18  23  98.7  74.2  82.3  4.961  181.4  11.2           0           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# DET17-18           1            0            1            1            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# DET17-18            0            0            1            1            2
#
# ...

# %% [markdown]
# ## CHI

# %%
CHI_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='CHI']
CHI_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  \
# Name
# Kris Dunn         7.8  0.457  17.0  1.4  0.321  4.3  9.9  33.3   23  0.9
# Jerian Grant      4.3  0.468   9.1  1.8  0.326  5.4  9.9  30.1   25  0.2
# Justin Holiday    2.8  0.387   7.2  3.5  0.359  9.7  3.3  10.1   28  0.7
# David Nwaba       5.5  0.496  11.0  0.5  0.346  1.5  3.1   9.4   25  0.9
# Denzel Valentine  3.7  0.450   8.2  3.3  0.386  8.6  5.7  17.8   24  0.3
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT  \
# Name
# Kris Dunn          1.6 -0.1   1.4  6.3  14.4   107  9.2  0.429  21.3  2.7
# Jerian Grant       0.4 -2.0  -1.8  4.1   9.3   112  6.1  0.416  14.6  4.1
# Justin Holiday     1.2 -1.3  -0.3  5.6  12.8   111  6.2  0.371  16.9  2.9
# David Nwaba        1.6 -1.6   0.9  7.0  16.0   110  6.0  0.478  12.5  3.9
# Denzel Valentine   0.5 -0.5  -0.1  8.0  18.3   111  7.0  0.417  16.8  0.9
#
# ...

# %%
CHI_17_18.drop(['Paul Zipser'], inplace=True)
CHI_17_18.drop(columns=['Pos'], inplace=True)
CHI_17_18_sum = pd.DataFrame(CHI_17_18.sum(axis=0))
CHI_17_18_sum.loc['Tm', 0]= 'CHI17-18'
CHI_17_18_sum = CHI_17_18_sum.T.set_index('Tm')
CHI_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST AST%  Age  BLK  BLK%  \
# Tm
# CHI17-18  54.7  4.401  109.9  16.5  2.745  46.3  43.8  141  221  6.7  12.2
#
#            BPM DBPM   DRB   DRB% DRtg  FG    FG%    FGA    FT   FT%   FTA  \
# Tm
# CHI17-18 -11.4 -2.2  63.5  144.9  998  71  4.137  156.3  26.2  6.74  34.9
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER  PF    PTS   STL  STL%  \
# Tm
# CHI17-18  605  351  15547   -9  20.7  43.9  954  126.4  36  184.7  13.6  13.6
#
#            TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0 c_cluster_1  \
# Tm
# CHI17-18  24.9  115.1  84.4  92.6  4.864  175.3    3           1           1
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# CHI17-18           0            0            2            0            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# CHI17-18            0            0            2            0            0
#
# ...

# %% [markdown]
# ## MIA

# %%
MIA_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='MIA']
MIA_17_18.head()
# Out:
#                   2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Goran Dragic     7.9  0.481  16.4  2.3  0.370   6.3  7.6  25.4   31  0.3
# Tyler Johnson    4.6  0.491   9.5  2.9  0.367   7.9  4.0  12.4   25  0.8
# Wayne Ellington  1.4  0.479   3.0  5.6  0.392  14.2  1.9   5.9   30  0.2
# Josh Richardson  5.1  0.495  10.3  2.4  0.378   6.3  4.3  13.2   24  1.4
# James Johnson    6.5  0.587  11.1  1.5  0.308   4.8  7.2  22.5   30  1.3
#
#                  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Goran Dragic      0.4 -0.1  -1.1  5.3  12.0   109  10.2  0.450  22.7  4.6
# Tyler Johnson     1.4 -0.2  -0.1  5.2  11.7   108   7.6  0.435  17.4  2.6
# Wayne Ellington   0.3  0.0  -1.8  4.8  10.7   110   7.0  0.407  17.2  1.6
# Josh Richardson   2.4  1.4   1.5  4.0   9.0   106   7.4  0.451  16.5  2.2
# James Johnson     2.2  1.7   1.7  7.7  17.2   105   8.0  0.503  15.9  2.9
#
# ...

# %%
MIA_17_18.drop(columns=['Pos'], inplace=True)
MIA_17_18_sum = pd.DataFrame(MIA_17_18.sum(axis=0))
MIA_17_18_sum.loc['Tm', 0]= 'MIA17-18'
MIA_17_18_sum = MIA_17_18_sum.T.set_index('Tm')
MIA_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST AST%  Age BLK  BLK%  \
# Tm
# MIA17-18  53.9  4.624  104.4  19.3  3.574  51.7  40.9  129  235  11  18.5
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%  FGA    FT    FT% FTA    G  \
# Tm
# MIA17-18  5.1  7.3  71.8  160.8  952  73.2  4.219  156  29.1  6.854  39  645
#
#            GS     MP OBPM   ORB ORB% ORtg    PER    PF    PTS   STL  STL%  \
# Tm
# MIA17-18  358  17294 -2.3  20.5   46  985  140.6  38.8  194.9  14.1  14.1
#
#            TOV TOV%   TRB   TRB%    TS%   USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# MIA17-18  25.2  114  92.6  103.2  5.057  177.5  11.4           1           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# MIA17-18           1            0            0            3            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# MIA17-18            0            0            1            1            0
#
# ...

# %% [markdown]
# ### WAS

# %%
WAS_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='WAS']
WAS_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  \
# Name
# Tim Frazier       3.0  0.440   6.9  1.0  0.304  3.3  11.5  31.1   27  0.4
# John Wall         7.7  0.436  17.6  2.2  0.371  5.9  13.8  44.5   27  1.6
# Bradley Beal      8.1  0.507  15.9  3.3  0.375  8.8   6.2  21.0   24  0.6
# Jodie Meeks       3.8  0.464   8.1  3.2  0.343  9.3   3.1   9.1   30  0.2
# Tomas Satoransky  4.7  0.544   8.6  1.4  0.465  3.1   8.6  24.8   26  0.5
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Tim Frazier        0.7 -2.1   0.3  5.7  13.1   107   4.0  0.395  10.2  1.4
# John Wall          2.8  1.5   0.0  4.5  10.2   108   9.9  0.420  23.5  6.2
# Bradley Beal       1.1  1.7  -1.0  5.0  11.5   110  11.4  0.460  24.8  4.9
# Jodie Meeks        0.3 -2.8  -2.5  4.9  11.2   112   7.0  0.399  17.4  4.5
# Tomas Satoransky   0.8  1.1  -0.2  4.9  11.1   111   6.1  0.523  11.6  2.3
#
# ...

# %%
WAS_17_18.drop(['Tim Frazier', 'Jodie Meeks'], inplace=True)

# %%
WAS_17_18.drop(columns=['Pos'], inplace=True)
WAS_17_18_sum = pd.DataFrame(WAS_17_18.sum(axis=0))
WAS_17_18_sum.loc['Tm', 0]= 'WAS17-18'
WAS_17_18_sum = WAS_17_18_sum.T.set_index('Tm')
WAS_17_18_sum
# Out:
#             2P   2P%    2PA    3P    3P%   3PA   AST   AST%  Age BLK  BLK%  \
# Tm
# WAS17-18  57.8  4.67  112.2  16.7  2.765  43.5  46.3  144.1  244   9  15.7
#
#           BPM DBPM   DRB   DRB% DRtg    FG   FG%    FGA    FT    FT%   FTA  \
# Tm
# WAS17-18  3.5  1.8  62.8  142.7  978  74.5  4.39  155.6  30.8  6.802  40.8
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# WAS17-18  662  397  17287  1.8  21.3  48.5  997  136.9  42.7  196.5  14.2
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0  \
# Tm
# WAS17-18  14.2  27.9  126.6  83.9  95.6  5.142  178.8  11.2           2
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# WAS17-18           0           0            0            0            2
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# WAS17-18            0            0            0            0            1
#
# ...

# %% [markdown]
# ### CHO

# %%
CHO_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='CHO']
CHO_17_18.head()
# Out:
#                           2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  \
# Name
# Michael Carter-Williams  3.6  0.365   9.9  0.8  0.237   3.4  6.8  19.4   26
# Kemba Walker             6.4  0.469  13.6  4.1  0.384  10.7  7.9  27.4   27
# Dwayne Bacon             4.2  0.409  10.2  0.8  0.256   2.9  2.6   7.5   22
# Nicolas Batum            4.4  0.473   9.3  2.3  0.336   6.7  8.6  26.2   29
# Treveon Graham           2.6  0.452   5.8  1.9  0.412   4.5  2.7   7.8   24
#
#                          BLK  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%  \
# Name
# Michael Carter-Williams  1.3   2.3 -0.6   2.0  5.9  13.3   107   4.4  0.332
# Kemba Walker             0.4   0.7  3.2  -1.9  3.9   8.7   111  10.5  0.431
# Dwayne Bacon             0.1   0.2 -5.7  -0.3  8.2  18.5   111   4.9  0.375
# Nicolas Batum            0.6   1.0  1.4   0.5  6.1  13.8   110   6.6  0.415
# Treveon Graham           0.1   0.2 -0.9  -0.3  3.7   8.3   112   4.5  0.434
#
# ...

# %%
CHO_17_18.drop(['Michael Carter-Williams','Dwayne Bacon'], inplace=True)

# %%
CHO_17_18.drop(columns=['Pos'], inplace=True)
CHO_17_18_sum = pd.DataFrame(CHO_17_18.sum(axis=0))
CHO_17_18_sum.loc['Tm', 0]= 'CHO17-18'
CHO_17_18_sum = CHO_17_18_sum.T.set_index('Tm')
CHO_17_18_sum
# Out:
#             2P    2P%  2PA    3P   3P% 3PA   AST   AST%  Age  BLK  BLK%  BPM  \
# Tm
# CHO17-18  50.5  4.309  104  21.2  2.78  57  38.7  124.7  235  7.2  12.5 -1.1
#
#          DBPM   DRB   DRB% DRtg    FG    FG%  FGA    FT    FT% FTA    G   GS  \
# Tm
# CHO17-18   -4  58.1  131.2  988  71.6  4.043  161  33.6  6.979  45  662  401
#
#              MP OBPM   ORB  ORB% ORtg    PER    PF  PTS STL STL%   TOV TOV%  \
# Tm
# CHO17-18  16742    3  15.9  34.7  989  132.6  29.4  198  12   12  21.7   95
#
#          TRB  TRB%    TS% USG%  VORP c_cluster_0 c_cluster_1 c_cluster_2  \
# Tm
# CHO17-18  74  82.1  4.945  180  10.2           0           0           1
#
#          pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3 pf_cluster_4  \
# Tm
# CHO17-18            0            1            1            0            0
#
#          pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0 sf_cluster_1  \
# Tm
# CHO17-18            0            0            1            0            1
#
# ...

# %% [markdown]
# ### ORL

# %%
ORL_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='ORL']
ORL_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  \
# Name
# D.J. Augustin     3.6  0.485   7.5  3.2  0.419  7.6  8.0  24.4   30  0.0
# Shelvin Mack      4.7  0.473   9.9  1.7  0.345  5.0  9.8  29.5   27  0.3
# Arron Afflalo     2.7  0.413   6.6  1.9  0.386  5.0  2.2   6.2   32  0.6
# Jonathon Simmons  6.9  0.512  13.4  1.7  0.338  4.9  4.1  13.3   28  0.4
# Evan Fournier     6.4  0.516  12.4  3.4  0.379  8.9  4.4  14.8   25  0.4
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT  \
# Name
# D.J. Augustin      0.0 -0.9  -2.5  3.6   8.2   113  6.8  0.452  15.0  4.6
# Shelvin Mack       0.5 -2.4  -1.2  5.1  11.6   111  6.4  0.430  14.8  2.5
# Arron Afflalo      1.1 -5.8  -1.8  4.5  10.1   115  4.7  0.401  11.6  1.6
# Jonathon Simmons   0.6 -2.3  -1.3  4.3   9.7   113  8.5  0.465  18.4  4.5
# Evan Fournier      0.7 -0.4  -2.1  4.2   9.5   113  9.8  0.459  21.4  4.0
#
# ...

# %%
ORL_17_18.drop(['Arron Afflalo','Marreese Speights','Khem Birch'], inplace=True)

# %%
ORL_17_18.drop(columns=['Pos'], inplace=True)
ORL_17_18_sum = pd.DataFrame(ORL_17_18.sum(axis=0))
ORL_17_18_sum.loc['Tm', 0]= 'ORL17-18'
ORL_17_18_sum = ORL_17_18_sum.T.set_index('Tm')
ORL_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# ORL17-18  53.4  4.542  105.2  17.9  2.664  51.2  43.4  137.9  229  8.7  14.2
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# ORL17-18 -9.2 -2.5  61.5  139.4  992  71.3  4.104  156.4  29.2  6.923  38.2
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# ORL17-18  604  327  14755 -6.9  16.4  37.1  954  128.7  33.9  189.6  13.9
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# ORL17-18  13.9  25.2  117.3  78.2  87.8  4.908  178.5  4.2           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# ORL17-18           0           1            0            1            0
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# ORL17-18            0            0            0            2            0
#
# ...

# %% [markdown]
# ### ATL

# %%
ATL_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='ATL']
ATL_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Malcolm Delaney   3.0  0.391   7.8  2.2  0.371   6.0  7.9  23.4   28  0.3
# Dennis Schroder  10.0  0.480  20.8  1.8  0.290   6.2  9.8  36.2   24  0.1
# Isaiah Taylor     6.0  0.461  13.0  0.8  0.250   3.3  8.6  27.0   23  0.4
# Kent Bazemore     4.8  0.438  11.0  2.9  0.394   7.5  6.2  20.1   28  1.2
# Tyler Dorsey      3.6  0.393   9.2  3.6  0.362  10.0  4.0  12.5   21  0.3
#
#                  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Malcolm Delaney   0.5 -3.6  -1.5  4.4  10.0   113   5.3  0.382  13.7  3.6
# Dennis Schroder   0.2 -0.7  -2.2  3.9   8.8   113  11.8  0.436  26.9  5.3
# Isaiah Taylor     0.7 -5.4  -2.5  3.0   6.9   114   6.8  0.418  16.3  4.1
# Kent Bazemore     2.2  0.4   1.1  6.1  13.9   108   7.8  0.420  18.5  4.4
# Tyler Dorsey      0.4 -4.2  -2.5  5.7  12.9   114   7.2  0.377  19.2  2.3
#
# ...

# %%
ATL_17_18.drop(['Miles Plumlee'], inplace=True)

# %%
ATL_17_18.drop(columns=['Pos'], inplace=True)
ATL_17_18_sum = pd.DataFrame(ATL_17_18.sum(axis=0))
ATL_17_18_sum.loc['Tm', 0]= 'ATL17-18'
ATL_17_18_sum = ATL_17_18_sum.T.set_index('Tm')
ATL_17_18_sum
# Out:
#             2P    2P%  2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# ATL17-18  50.3  4.376  103  19.7  3.118  55.6  48.6  158.5  221  8.1  14.3
#
#            BPM DBPM   DRB DRB% DRtg    FG    FG%    FGA  FT    FT%   FTA    G  \
# Tm
# ATL17-18 -11.8 -3.9  60.1  137  998  70.2  4.017  158.3  31  7.122  39.5  580
#
#            GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  STL%  \
# Tm
# ATL17-18  310  13873 -7.7  15.5  35.5  953  124.6  37.5  191.1  14.1  14.1
#
#            TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0 c_cluster_1  \
# Tm
# ATL17-18  28.5  125.5  75.5  86.2  4.932  182.6    4           0           2
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# ATL17-18           0            0            0            0            1
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# ATL17-18            0            0            2            1            0
#
# ...

# %% [markdown]
# ### POR

# %%
POR_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='POR']
POR_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Damian Lillard    7.3  0.501  14.6  4.2  0.361  11.7  9.0  30.9   27  0.5
# Shabazz Napier    4.6  0.450  10.1  2.7  0.376   7.1  4.9  14.6   26  0.5
# Pat Connaughton   3.0  0.506   6.0  2.5  0.352   7.0  3.0   8.7   25  0.7
# CJ McCollum       8.1  0.465  17.5  3.2  0.397   8.1  4.6  15.8   26  0.6
# Maurice Harkless  3.9  0.547   7.0  1.9  0.415   4.6  2.1   6.0   24  1.7
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Damian Lillard     0.8  6.7  -1.0  4.9  10.6   109  11.6  0.439  26.4  9.2
# Shabazz Napier     0.7  0.2   0.3  4.7  10.1   106   7.2  0.420  17.2  3.8
# Pat Connaughton    1.2 -1.3  -0.4  4.2   9.1   110   5.5  0.423  13.0  1.2
# CJ McCollum        1.0  0.4  -1.0  4.6   9.9   109  11.4  0.443  25.6  3.6
# Maurice Harkless   2.8  1.8   2.0  4.6   9.9   106   5.8  0.495  11.7  1.7
#
# ...

# %%
POR_17_18.drop(['Zach Collins'], inplace=True)

# %%
POR_17_18.drop(columns=['Pos'], inplace=True)
POR_17_18_sum = pd.DataFrame(POR_17_18.sum(axis=0))
POR_17_18_sum.loc['Tm', 0]= 'POR17-18'
POR_17_18_sum = POR_17_18_sum.T.set_index('Tm')
POR_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P% 3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# POR17-18  51.8  4.478  104.2  18.5  2.588  50  34.6  109.8  235  10.1  16.5
#
#           BPM DBPM   DRB DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# POR17-18  7.4    7  64.2  139  957  70.4  4.149  154.6  29.7  7.031  37.4
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# POR17-18  674  391  17545  0.2  19.6  43.7  993  134.9  35.5  189.3  13.6
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0  \
# Tm
# POR17-18  13.6  23.2  109.2  83.8  91.6  4.986  171.5  13.6           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# POR17-18           0           1            0            0            1
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# POR17-18            0            0            0            1            1
#
# ...

# %% [markdown]
# ### OKC

# %%
OKC_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='OKC']
OKC_17_18.head()
# Out:
#                      2P    2P%   2PA   3P    3P%   3PA   AST  AST%  Age  BLK  \
# Name
# Raymond Felton      5.2  0.444  11.7  2.9  0.352   8.4   7.4  22.5   33  0.6
# Russell Westbrook  11.2  0.485  23.2  1.7  0.298   5.6  14.0  49.8   29  0.3
# Alex Abrines        1.4  0.443   3.1  3.7  0.380   9.7   1.2   3.4   24  0.4
# Terrance Ferguson   2.0  0.612   3.2  2.6  0.333   7.8   1.2   3.4   19  0.7
# Paul George         5.7  0.454  12.5  4.2  0.401  10.5   4.5  14.5   27  0.7
#
#                    BLK%  BPM  DBPM   DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Raymond Felton      1.1 -2.8  -1.7   4.8  11.0   109   8.1  0.406  20.1  1.3
# Russell Westbrook   0.6  8.2   3.1  11.1  25.7   104  12.9  0.449  28.7  7.1
# Alex Abrines        0.6 -2.2  -1.7   3.9   8.9   110   5.0  0.395  12.7  1.7
# Terrance Ferguson   1.2 -2.5  -1.3   1.8   4.2   111   4.6  0.414  11.0  0.6
# Paul George         1.2  2.6   0.0   6.4  14.9   106   9.9  0.430  23.0  5.8
#
# ...

# %%
OKC_17_18.drop(['Terrance Ferguson'], inplace=True)

# %%
OKC_17_18.drop(columns=['Pos'], inplace=True)
OKC_17_18_sum = pd.DataFrame(OKC_17_18.sum(axis=0))
OKC_17_18_sum.loc['Tm', 0]= 'OKC17-18'
OKC_17_18_sum = OKC_17_18_sum.T.set_index('Tm')
OKC_17_18_sum
# Out:
#             2P    2P% 2PA    3P    3P%   3PA   AST   AST%  Age BLK  BLK%  BPM  \
# Tm
# OKC17-18  47.8  4.331  96  21.2  2.752  59.4  35.8  116.1  247  10  17.9 -0.5
#
#          DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA    G  \
# Tm
# OKC17-18  0.1  59.2  136.9  970  68.7  3.976  155.2  28.8  6.396  39.8  702
#
#            GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  STL%  \
# Tm
# OKC17-18  337  17191 -0.7  20.8  45.2  998  130.3  36.5  187.3  15.1  15.1
#
#            TOV  TOV% TRB  TRB%    TS%   USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# OKC17-18  22.8  99.3  80  89.3  4.867  169.1  12.9           1           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# OKC17-18           0            2            1            1            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# OKC17-18            0            1            1            0            0
#
# ...

# %% [markdown]
# ### UTA

# %%
UTA_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='UTA']
UTA_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Raul Neto         5.0  0.481  10.5  1.9  0.404   4.7  7.6  23.0   25  0.4
# Ricky Rubio       5.6  0.451  12.3  2.1  0.352   6.1  9.1  28.4   27  0.2
# Alec Burks        5.8  0.452  12.9  2.2  0.331   6.7  3.2  10.0   26  0.4
# Donovan Mitchell  7.8  0.502  15.4  3.6  0.340  10.5  5.5  19.4   21  0.5
# Joe Ingles        2.5  0.516   4.9  4.0  0.440   9.0  7.6  22.9   30  0.4
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Raul Neto          0.7 -3.2  -1.1  4.2   9.5   108   6.9  0.457  15.2  2.6
# Ricky Rubio        0.4  1.7   1.6  6.8  15.3   103   7.7  0.418  18.4  4.9
# Alec Burks         0.6 -2.8  -0.3  8.2  18.4   105   8.1  0.411  19.6  5.1
# Donovan Mitchell   0.9  1.1  -0.2  4.6  10.4   105  11.3  0.437  25.9  4.5
# Joe Ingles         0.7  3.1   1.0  6.2  13.9   106   6.5  0.467  14.0  1.3
#
# ...

# %%
UTA_17_18.drop(['Raul Neto'], inplace=True)

# %%
UTA_17_18.drop(columns=['Pos'], inplace=True)
UTA_17_18_sum = pd.DataFrame(UTA_17_18.sum(axis=0))
UTA_17_18_sum.loc['Tm', 0]= 'UTA17-18'
UTA_17_18_sum = UTA_17_18_sum.T.set_index('Tm')
UTA_17_18_sum
# Out:
#             2P    2P%   2PA    3P    3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# UTA17-18  49.5  4.624  95.4  16.9  2.455  45.9  39.3  122.2  239  12.8  21.6
#
#            BPM  DBPM   DRB   DRB% DRtg    FG    FG%    FGA  FT    FT%   FTA  \
# Tm
# UTA17-18  14.6  17.1  68.8  154.6  930  66.3  4.307  141.5  32  7.022  41.4
#
#             G   GS     MP OBPM   ORB  ORB%  ORtg    PER    PF    PTS   STL  \
# Tm
# UTA17-18  641  389  15592 -2.6  20.2  46.2  1015  138.3  40.4  181.7  16.4
#
#           STL%   TOV   TOV%   TRB TRB%    TS%   USG%  VORP c_cluster_0  \
# Tm
# UTA17-18  16.4  24.4  118.9  89.2  101  5.164  165.1  15.1           3
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# UTA17-18           0           0            0            0            1
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# UTA17-18            0            0            0            1            0
#
# ...

# %% [markdown]
# ### MIN

# %%
MIN_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='MIN']
MIN_17_18.head()
# Out:
#                  2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  BLK%  \
# Name
# Tyus Jones      3.6  0.528   6.8  1.5  0.349  4.4   7.9  21.2   21  0.2   0.4
# Jeff Teague     5.8  0.477  12.2  1.8  0.368  4.9  10.6  30.6   29  0.5   0.8
# Jimmy Butler    8.5  0.509  16.7  1.6  0.350  4.6   6.7  20.6   28  0.6   1.0
# Jamal Crawford  6.2  0.477  12.9  3.1  0.331  9.5   5.6  16.9   37  0.3   0.5
# Andrew Wiggins  7.7  0.475  16.1  1.9  0.331  5.7   2.7   8.2   22  0.9   1.5
#
#                 BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT    FT%  \
# Name
# Tyus Jones      0.5  -0.3  4.0   9.2   110   5.1  0.457  11.2  2.4  0.877
# Jeff Teague     0.2  -1.3  4.0   9.3   112   7.7  0.446  17.2  4.4  0.845
# Jimmy Butler    5.0   0.1  5.4  12.7   110  10.1  0.474  21.3  8.4  0.854
# Jamal Crawford -3.9  -4.0  2.4   5.5   116   9.3  0.415  22.4  3.1  0.903
# Andrew Wiggins -2.5  -1.4  4.6  10.8   113   9.6  0.438  21.8  3.4  0.643
#
# ...

# %%
MIN_17_18.drop(columns=['Pos'], inplace=True)
MIN_17_18_sum = pd.DataFrame(MIN_17_18.sum(axis=0))
MIN_17_18_sum.loc['Tm', 0]= 'MIN17-18'
MIN_17_18_sum = MIN_17_18_sum.T.set_index('Tm')
MIN_17_18_sum
# Out:
#             2P    2P%  2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# MIN17-18  58.2  4.662  112  15.6  3.076  43.6  44.5  129.7  248  7.7  13.2
#
#          BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# MIN17-18   6 -5.1  58.5  136.1  999  73.8  4.292  155.6  34.5  7.323  42.2
#
#             G   GS     MP OBPM   ORB ORB%  ORtg    PER  PF    PTS   STL  STL%  \
# Tm
# MIN17-18  683  407  18922   11  18.4   42  1033  147.8  34  197.6  16.5  16.5
#
#            TOV   TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# MIN17-18  21.9  102.8  76.8  88.7  5.119  173.5  13.8           0           1
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# MIN17-18           1            0            0            2            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# MIN17-18            0            0            2            0            0
#
# ...

# %% [markdown]
# ### DEN

# %%
season_17_18_cluster.loc['Emmanuel Mudiay', 'Tm'] = 'DEN'

# %%
DEN_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='DEN']
DEN_17_18.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Emmanuel Mudiay  6.3  0.415  15.0  1.9  0.318  5.9  8.2  24.5   21  0.4   0.8
# Jamal Murray     6.1  0.502  12.1  3.2  0.378  8.4  5.3  16.4   20  0.5   0.9
# Will Barton      5.7  0.510  11.2  2.9  0.370  7.8  6.1  18.5   27  1.0   1.6
# Malik Beasley    3.8  0.469   8.2  2.4  0.341  7.0  2.6   7.4   21  0.6   1.0
# Gary Harris      6.1  0.553  11.1  3.4  0.396  8.5  4.2  13.0   23  0.3   0.5
#
#                  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT    FT%  \
# Name
# Emmanuel Mudiay -4.7  -2.1  5.0  11.3   113  8.1  0.388  20.9  3.9  0.760
# Jamal Murray    -0.2  -2.0  4.2   9.4   113  9.3  0.451  20.5  4.4  0.905
# Will Barton      1.0  -0.6  6.3  14.2   112  8.6  0.452  19.0  3.4  0.805
# Malik Beasley   -5.1  -2.4  4.8  11.0   113  6.2  0.410  15.1  1.9  0.667
# Gary Harris      0.9  -1.5  3.0   6.8   112  9.5  0.485  19.5  2.9  0.827
#
# ...

# %%
DEN_17_18.drop(columns=['Pos'], inplace=True)
DEN_17_18_sum = pd.DataFrame(DEN_17_18.sum(axis=0))
DEN_17_18_sum.loc['Tm', 0]= 'DEN17-18'
DEN_17_18_sum = DEN_17_18_sum.T.set_index('Tm')
DEN_17_18_sum
# Out:
#             2P    2P%    2PA  3P    3P%   3PA   AST   AST%  Age  BLK BLK%  \
# Tm
# DEN17-18  54.4  4.653  104.9  21  2.938  56.3  47.2  143.4  213  8.8   15
#
#           BPM DBPM   DRB   DRB%  DRtg  FG    FG%    FGA    FT   FT%   FTA  \
# Tm
# DEN17-18 -0.9 -5.4  61.5  139.1  1000  75  4.222  161.1  30.2  6.75  40.6
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF  PTS STL STL%  \
# Tm
# DEN17-18  651  371  16999  4.4  18.6  42.2  996  139.5  33.2  201  14   14
#
#            TOV   TOV%   TRB  TRB%   TS%   USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# DEN17-18  27.1  117.7  80.1  90.8  5.04  180.9  11.5           1           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# DEN17-18           1            0            1            0            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# DEN17-18            0            0            2            0            1
#
# ...

# %% [markdown]
# ### GSW

# %%
GSW_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='GSW']
GSW_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Stephen Curry     6.4  0.595  10.7  6.3  0.423  14.8  9.2  30.3   29  0.2
# Shaun Livingston  7.3  0.509  14.4  0.0  0.000   0.2  6.0  16.8   32  0.9
# Patrick McCaw     3.7  0.503   7.3  1.0  0.238   4.0  4.1  10.6   22  0.5
# Klay Thompson     6.7  0.526  12.7  4.4  0.440  10.0  3.6  11.2   27  0.7
# Nick Young        2.7  0.481   5.6  4.3  0.377  11.3  1.2   3.5   32  0.2
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Stephen Curry      0.4  8.6  -1.3  6.6  14.4   108  12.6  0.495  25.5  8.2
# Shaun Livingston   1.5 -3.5  -0.9  4.2   9.2   110   7.3  0.501  14.6  2.1
# Patrick McCaw      0.8 -3.4  -0.5  3.3   7.2   110   4.6  0.409  11.3  1.3
# Klay Thompson      1.1 -0.6  -2.4  4.7  10.3   111  11.1  0.488  22.7  1.6
# Nick Young         0.4 -3.7  -3.4  3.6   7.9   112   7.0  0.412  16.9  1.9
#
# ...

# %%
GSW_17_18.drop(['Patrick McCaw','Omri Casspi', 'Jordan Bell', 'Kevon Looney', 'JaVale McGee'], inplace=True)

# %%
GSW_17_18.drop(columns=['Pos'], inplace=True)
GSW_17_18_sum = pd.DataFrame(GSW_17_18.sum(axis=0))
GSW_17_18_sum.loc['Tm', 0]= 'GSW17-18'
GSW_17_18_sum = GSW_17_18_sum.T.set_index('Tm')
GSW_17_18_sum
# Out:
#           2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# GSW17-18  58  4.948  104.6  21.3  2.617  54.2  56.6  168.2  280  11.9  19.7
#
#            BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# GSW17-18  13.6  0.8  63.5  138.2  970  79.2  4.464  158.8  32.2  7.301  38.6
#
#             G   GS     MP  OBPM ORB  ORB%  ORtg    PER    PF  PTS   STL  STL%  \
# Tm
# GSW17-18  619  341  14864  12.9  15  37.2  1021  157.1  35.6  212  15.1  15.1
#
#            TOV   TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0 c_cluster_1  \
# Tm
# GSW17-18  28.9  130.1  78.5  91.3  5.312  186.8  14.7           1           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# GSW17-18           1            0            0            1            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# GSW17-18            1            0            1            1            0
#
# ...

# %% [markdown]
# ### LAC

# %%
season_17_18_cluster.loc['Tobias Harris', 'Tm'] = 'LAC'

# %%
LAC_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='LAC']
LAC_17_18.head()
# Out:
#                       2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  \
# Name
# Jawun Evans          4.6  0.372  12.4  0.9  0.278  3.4  6.3  17.8   21  0.4
# Milos Teodosic       2.7  0.492   5.5  3.8  0.379  9.9  9.0  26.2   30  0.2
# Austin Rivers        4.8  0.461  10.5  3.2  0.378  8.5  5.7  17.5   25  0.4
# Sindarius Thornwell  3.2  0.448   7.2  1.0  0.377  2.6  2.9   7.8   23  1.1
# Lou Williams         7.4  0.484  15.4  3.5  0.359  9.7  7.8  26.3   31  0.4
#
#                      BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Jawun Evans           0.6 -4.7  -0.5  4.7  10.4   111   5.6  0.352  15.8  2.4
# Milos Teodosic        0.4 -1.4  -2.2  4.7  10.5   114   6.5  0.419  15.4  1.7
# Austin Rivers         0.6 -0.9  -1.7  2.8   6.2   113   8.1  0.424  19.0  2.4
# Sindarius Thornwell   1.8 -1.6   1.0  4.5  10.0   111   4.2  0.429   9.8  2.5
# Lou Williams          0.6  1.0  -2.9  3.0   6.6   113  10.9  0.435  25.1  8.1
#
# ...

# %%
LAC_17_18.drop(['Jawun Evans'], inplace=True)

# %%
LAC_17_18.drop(columns=['Pos'], inplace=True)
LAC_17_18_sum = pd.DataFrame(LAC_17_18.sum(axis=0))
LAC_17_18_sum.loc['Tm', 0]= 'LAC17-18'
LAC_17_18_sum = LAC_17_18_sum.T.set_index('Tm')
LAC_17_18_sum
# Out:
#           2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# LAC17-18  55  4.723  102.1  17.5  2.553  48.3  38.2  118.6  240  8.6  14.7
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# LAC17-18 -0.5 -3.7  59.8  133.2  993  72.6  4.349  150.4  30.2  6.477  42.3
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# LAC17-18  638  332  15690  3.1  18.4  42.2  992  135.9  36.5  192.9  13.6
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# LAC17-18  13.6  24.2  116.5  78.2  88.2  5.089  171.5  9.4           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# LAC17-18           0           1            0            1            1
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# LAC17-18            0            0            0            1            0
#
# ...

# %% [markdown]
# ### LAL

# %%
LAL_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='LAL']
LAL_17_18.head()
# Out:
#                            2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  \
# Name
# Lonzo Ball                3.0  0.420   7.2  2.4  0.305  7.9  10.1  29.2   20
# Tyler Ennis               5.6  0.476  11.8  1.0  0.250  3.9   7.4  21.9   23
# Kentavious Caldwell-Pope  3.5  0.473   7.5  3.1  0.383  8.1   3.2   9.4   24
# Josh Hart                 3.2  0.551   5.8  2.6  0.396  6.5   2.6   7.6   22
# Brandon Ingram            7.7  0.483  15.9  1.0  0.390  2.5   5.6  17.7   20
#
#                           BLK  BLK%  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%  \
# Name
# Lonzo Ball                1.2   2.0  1.7   2.5  7.8  17.3   106  5.5  0.360
# Tyler Ennis               0.7   1.2 -2.9  -0.1  5.3  11.8   108  6.6  0.420
# Kentavious Caldwell-Pope  0.3   0.5  1.0   0.4  6.4  14.1   108  6.6  0.426
# Josh Hart                 0.5   0.9 -0.1   0.2  7.2  16.0   109  5.8  0.469
# Brandon Ingram            1.0   1.8 -1.3   0.3  6.2  13.8   109  8.7  0.470
#
# ...

# %%
LAL_17_18.drop(columns=['Pos'], inplace=True)
LAL_17_18_sum = pd.DataFrame(LAL_17_18.sum(axis=0))
LAL_17_18_sum.loc['Tm', 0]= 'LAL17-18'
LAL_17_18_sum = LAL_17_18_sum.T.set_index('Tm')
LAL_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# LAL17-18  54.2  4.542  106.1  16.6  2.657  47.6  42.7  131.1  203  9.9  16.8
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# LAL17-18 -3.7  3.6  66.3  146.7  971  70.8  4.118  153.6  29.6  6.275  41.4
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# LAL17-18  578  375  15093 -7.2  20.3  45.2  965  128.6  38.7  187.3  12.8
#
#           STL%   TOV   TOV%   TRB  TRB%    TS% USG% VORP c_cluster_0  \
# Tm
# LAL17-18  12.8  26.6  119.6  86.5  96.3  4.879  176  7.7           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# LAL17-18           1           1            0            1            0
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# LAL17-18            0            0            1            1            0
#
# ...

# %% [markdown]
# ### SAC

# %%
SAC_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='SAC']
SAC_17_18.head()
# Out:
#                     2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# De'Aaron Fox       7.0  0.436  16.1  1.2  0.307   3.8  8.0  24.6   20  0.5
# Frank Mason        5.8  0.384  15.1  1.6  0.360   4.4  7.6  22.7   23  0.5
# Bogdan Bogdanovic  5.0  0.485  10.3  3.0  0.392   7.7  6.0  18.3   25  0.4
# Buddy Hield        6.0  0.457  13.1  4.4  0.431  10.2  3.9  12.8   24  0.5
# Garrett Temple     3.4  0.442   7.8  2.8  0.392   7.1  3.9  11.3   31  0.8
#
#                    BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# De'Aaron Fox        0.9 -4.4  -1.5  4.3  10.0   113   8.2  0.412  19.9  3.5
# Frank Mason         1.0 -3.4  -1.4  5.1  12.1   112   7.4  0.379  19.5  4.8
# Bogdan Bogdanovic   0.7 -1.0  -1.5  4.5  10.5   113   8.0  0.446  18.0  2.3
# Buddy Hield         1.0 -0.2  -1.4  6.3  14.8   111  10.4  0.446  23.3  1.8
# Garrett Temple      1.6 -1.9  -0.6  4.1   9.6   112   6.2  0.418  14.9  1.9
#
# ...

# %%
SAC_17_18.drop(['Frank Mason', 'Vince Carter'], inplace=True)

# %%
SAC_17_18.drop(columns=['Pos'], inplace=True)
SAC_17_18_sum = pd.DataFrame(SAC_17_18.sum(axis=0))
SAC_17_18_sum.loc['Tm', 0]= 'SAC17-18'
SAC_17_18_sum = SAC_17_18_sum.T.set_index('Tm')
SAC_17_18_sum
# Out:
#             2P    2P%    2PA    3P   3P%   3PA AST   AST%  Age  BLK  BLK%  \
# Tm
# SAC17-18  61.3  4.406  125.4  15.8  2.78  42.3  39  121.6  231  7.8  14.6
#
#            BPM DBPM   DRB   DRB%  DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# SAC17-18 -14.5 -4.5  63.5  148.9  1001  77.2  4.158  167.7  22.1  6.586  30.5
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER  PF    PTS   STL  STL%  \
# Tm
# SAC17-18  627  357  15529 -9.8  20.4  44.3  937  126.9  38  192.1  14.2  14.2
#
#            TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0 c_cluster_1  \
# Tm
# SAC17-18  25.5  109.1  83.9  94.3  4.785  183.6  1.8           1           0
#
#          c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2 pf_cluster_3  \
# Tm
# SAC17-18           1            0            2            0            0
#
#          pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2 sf_cluster_0  \
# Tm
# SAC17-18            0            0            1            0            1
#
# ...

# %% [markdown]
# ### PHO

# %%
PHO_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='PHO']
PHO_17_18.head()
# Out:
#                 2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Tyler Ulis     5.0  0.425  11.7  1.2  0.288   4.2  9.0  28.0   22  0.2   0.3
# Devin Booker   7.9  0.460  17.2  3.8  0.383   9.9  6.5  24.4   21  0.4   0.6
# Troy Daniels   1.4  0.419   3.5  5.4  0.400  13.5  1.4   4.5   26  0.1   0.2
# Josh Jackson   8.1  0.464  17.5  1.4  0.263   5.3  2.9  10.1   20  0.9   1.4
# T.J. Warren   11.4  0.523  21.7  0.4  0.222   2.0  1.9   7.2   24  0.9   1.5
#
#               BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT    FT%  FTA  \
# Name
# Tyler Ulis   -5.2  -2.4  3.0   6.8   115   6.2  0.388  15.9  2.4  0.832  2.9
# Devin Booker  0.4  -2.4  5.6  12.7   115  11.7  0.432  27.1  7.4  0.878  8.4
# Troy Daniels -2.9  -3.6  3.4   7.7   117   6.8  0.403  17.0  1.7  0.875  1.9
# Josh Jackson -4.3  -1.2  6.3  14.2   112   9.5  0.417  22.8  4.3  0.634  6.8
# T.J. Warren  -1.9  -1.7  4.6  10.5   114  11.8  0.498  23.8  4.3  0.757  5.7
#
# ...

# %%
PHO_17_18.drop(['Jared Dudley'], inplace=True)

# %%
PHO_17_18.drop(columns=['Pos'], inplace=True)
PHO_17_18_sum = pd.DataFrame(PHO_17_18.sum(axis=0))
PHO_17_18_sum.loc['Tm', 0]= 'PHO17-18'
PHO_17_18_sum = PHO_17_18_sum.T.set_index('Tm')
PHO_17_18_sum
# Out:
#             2P    2P%  2PA    3P   3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# PHO17-18  52.3  4.441  105  16.7  2.55  48.4  32.3  106.9  212  9.1  15.2
#
#            BPM DBPM   DRB   DRB%  DRtg    FG   FG%    FGA    FT    FT%   FTA  \
# Tm
# PHO17-18 -18.1 -7.9  63.9  144.9  1017  68.9  4.16  153.6  31.8  6.657  43.7
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# PHO17-18  615  357  15388  -10  21.8  47.6  945  119.2  40.4  186.6  11.2
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# PHO17-18  11.2  27.1  127.9  85.7  95.5  4.933  176.7 -0.4           2
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# PHO17-18           0           0            1            0            1
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# PHO17-18            0            0            0            1            0
#
# ...

# %% [markdown]
# ### HOU

# %%
HOU_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='HOU']
HOU_17_18.head()
# Out:
#                2P    2P%   2PA   3P    3P%   3PA   AST  AST%  Age  BLK  BLK%  \
# Name
# Chris Paul    5.9  0.532  11.2  3.8  0.380  10.1  12.2  40.9   32  0.4   0.6
# Eric Gordon   4.5  0.544   8.3  5.0  0.359  13.9   3.5  11.7   29  0.6   1.1
# Gerald Green  3.1  0.504   6.1  5.8  0.369  15.8   1.3   4.3   32  0.8   1.4
# James Harden  7.4  0.531  14.0  5.1  0.367  13.9  12.2  45.1   28  1.0   1.7
# Trevor Ariza  2.1  0.519   4.1  3.7  0.368  10.0   2.3   6.8   32  0.3   0.5
#
#                BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA    FT    FT%  \
# Name
# Chris Paul     7.1   0.9  7.4  16.7   105   9.8  0.460  21.3   5.4  0.919
# Eric Gordon   -1.0  -2.4  3.3   7.5   110   9.5  0.428  22.2   4.5  0.809
# Gerald Green  -1.9  -2.4  6.2  14.2   108   8.9  0.407  21.9   2.7  0.850
# James Harden  10.9   1.3  6.7  15.2   105  12.6  0.449  27.9  12.0  0.858
# Trevor Ariza   1.5   0.7  5.7  12.9   107   5.8  0.412  14.1   1.6  0.854
#
# ...

# %%
HOU_17_18.drop(['Tarik Black', 'Nene Hilario'], inplace=True)

# %%
HOU_17_18.drop(columns=['Pos'], inplace=True)
HOU_17_18_sum = pd.DataFrame(HOU_17_18.sum(axis=0))
HOU_17_18_sum.loc['Tm', 0]= 'HOU17-18'
HOU_17_18_sum = HOU_17_18_sum.T.set_index('Tm')
HOU_17_18_sum
# Out:
#             2P    2P%   2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# HOU17-18  40.3  4.856  72.2  31.6  2.964  85.5  38.2  129.2  268  8.4  14.4
#
#            BPM DBPM   DRB   DRB% DRtg    FG   FG%    FGA    FT    FT%   FTA  \
# Tm
# HOU17-18  19.8  3.2  62.8  142.2  957  72.1  4.11  157.9  34.7  7.025  43.7
#
#             G   GS     MP  OBPM   ORB  ORB%  ORtg    PER    PF    PTS   STL  \
# Tm
# HOU17-18  590  402  17354  16.6  15.1  34.8  1039  150.9  32.8  210.5  15.5
#
#           STL%   TOV  TOV%   TRB  TRB%    TS%   USG%  VORP c_cluster_0  \
# Tm
# HOU17-18  15.5  22.6  99.8  77.7  88.9  5.308  179.3  20.7           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# HOU17-18           0           0            1            0            2
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# HOU17-18            0            0            0            0            1
#
# ...

# %% [markdown]
# ### NOP

# %%
season_17_18_cluster.loc['Dante Cunningham', 'Tm']='NOP'

# %%
NOP_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='NOP']
NOP_17_18.head()
# Out:
#                    2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  \
# Name
# Rajon Rondo       5.1  0.526   9.6  1.4  0.333  4.2  14.9  42.2   31  0.3
# Ian Clark         5.2  0.533   9.8  2.0  0.318  6.4   3.6  10.4   26  0.3
# Jrue Holiday      8.1  0.557  14.5  2.0  0.337  5.8   7.9  24.9   27  1.0
# E'Twaun Moore     5.4  0.556   9.8  2.4  0.425  5.6   3.5  10.1   28  0.2
# Dante Cunningham  3.3  0.541   6.0  1.8  0.345  5.2   1.5   4.3   30  0.9
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# Rajon Rondo        0.5 -1.1  -0.7  6.5  14.2   109   6.5  0.468  13.8  0.7
# Ian Clark          0.5 -3.9  -2.0  3.8   8.4   112   7.3  0.448  16.2  1.5
# Jrue Holiday       1.7  2.1   0.3  4.9  10.8   109  10.0  0.494  20.3  3.1
# E'Twaun Moore      0.4 -0.2  -0.8  3.3   7.3   112   7.8  0.508  15.4  0.9
# Dante Cunningham   1.5 -1.4   0.1  6.8  14.9   110   5.0  0.451  11.2  1.0
#
# ...

# %%
NOP_17_18.drop(columns=['Pos'], inplace=True)
NOP_17_18_sum = pd.DataFrame(NOP_17_18.sum(axis=0))
NOP_17_18_sum.loc['Tm', 0]= 'NOP17-18'
NOP_17_18_sum = NOP_17_18_sum.T.set_index('Tm')
NOP_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# NOP17-18  58.2  4.916  105.9  17.1  2.863  46.9  45.8  137.9  241  10.3  17.3
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# NOP17-18  2.1  0.9  67.8  148.8  974  75.2  4.397  152.7  29.5  6.592  38.3
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# NOP17-18  632  377  17224    1  16.2  37.8  998  142.4  35.7  196.6  13.6
#
#           STL%   TOV   TOV%   TRB  TRB%    TS% USG%  VORP c_cluster_0  \
# Tm
# NOP17-18  13.6  25.7  114.3  84.1  95.2  5.184  177  12.6           0
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# NOP17-18           0           1            0            0            0
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# NOP17-18            1            1            0            1            0
#
# ...

# %% [markdown]
# ### SAS

# %%
SAS_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='SAS']
SAS_17_18.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Patty Mills      3.0  0.470   6.4  3.7  0.372  9.9  5.5  16.0   29  0.3   0.4
# Dejounte Murray  7.6  0.454  16.7  0.3  0.265  1.0  6.7  20.2   21  0.9   1.5
# Tony Parker      7.9  0.479  16.6  0.5  0.270  1.7  9.2  28.2   35  0.0   0.1
# Bryn Forbes      4.0  0.446   9.0  3.0  0.390  7.6  2.7   7.8   24  0.1   0.1
# Manu Ginobili    5.3  0.506  10.5  2.5  0.333  7.5  6.3  19.1   40  0.6   1.0
#
#                  BPM  DBPM   DRB  DRB%  DRtg   FG    FG%   FGA   FT    FT%  \
# Name
# Patty Mills     -0.4  -1.3   3.1   6.8   109  6.7  0.411  16.4  2.5  0.890
# Dejounte Murray  1.2   3.4  10.1  22.4   101  7.8  0.443  17.7  3.0  0.709
# Tony Parker     -4.1  -1.7   4.2   9.2   109  8.4  0.459  18.3  2.6  0.705
# Bryn Forbes     -3.1  -1.9   3.3   7.2   110  7.0  0.421  16.6  1.6  0.667
# Manu Ginobili   -1.0  -0.5   4.8  10.6   107  7.8  0.434  18.0  4.3  0.840
#
# ...

# %%
SAS_17_18.drop(['Tony Parker','Brandon Paul','Davis Bertans','Joffrey Lauvergne'], inplace=True)

# %%
SAS_17_18.drop(columns=['Pos'], inplace=True)
SAS_17_18_sum = pd.DataFrame(SAS_17_18.sum(axis=0))
SAS_17_18_sum.loc['Tm', 0]= 'SAS17-18'
SAS_17_18_sum = SAS_17_18_sum.T.set_index('Tm')
SAS_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# SAS17-18  57.1  4.374  115.7  16.5  3.021  46.5  42.2  127.9  268  11.3  18.4
#
#           BPM  DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# SAS17-18  8.8  10.8  65.5  144.6  942  73.5  4.062  162.3  31.2  6.952  39.9
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# SAS17-18  661  367  15987 -2.2  19.9  43.5  967  138.1  32.9  194.7  14.9
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# SAS17-18  14.9  24.6  110.9  85.3  93.7  4.866  180.9   13           0
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# SAS17-18           0           2            0            1            0
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# SAS17-18            0            0            1            1            0
#
# ...

# %% [markdown]
# ### DAL

# %%
DAL_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='DAL']
DAL_17_18.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA   AST  AST%  Age  BLK  \
# Name
# J.J. Barea       5.9  0.499  11.8  3.6  0.367  9.8  13.6  45.1   33  0.1
# Dennis Smith     7.3  0.435  16.8  2.6  0.313  8.3   8.8  29.5   20  0.4
# Yogi Ferrell     3.9  0.477   8.2  2.9  0.373  7.9   4.4  13.5   24  0.2
# Wesley Matthews  3.1  0.441   6.9  3.6  0.381  9.5   4.1  12.3   31  0.4
# Harrison Barnes  8.0  0.478  16.7  2.3  0.357  6.3   2.9   9.9   25  0.3
#
#                  BLK%  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT  \
# Name
# J.J. Barea        0.2  0.1  -2.3  5.8  13.4   112   9.5  0.439  21.6  2.5
# Dennis Smith      0.8 -2.3  -0.7  5.1  11.8   110   9.9  0.395  25.1  3.3
# Yogi Ferrell      0.4 -1.0  -0.6  4.9  11.2   112   6.8  0.426  16.1  1.8
# Wesley Matthews   0.7  0.1  -0.2  4.0   9.2   111   6.7  0.406  16.4  2.0
# Harrison Barnes   0.5 -2.1  -1.4  7.5  17.1   111  10.2  0.445  23.0  4.9
#
# ...

# %%
DAL_17_18.drop(columns=['Pos'], inplace=True)
DAL_17_18_sum = pd.DataFrame(DAL_17_18.sum(axis=0))
DAL_17_18_sum.loc['Tm', 0]= 'DAL17-18'
DAL_17_18_sum = DAL_17_18_sum.T.set_index('Tm')
DAL_17_18_sum
# Out:
#             2P   2P%   2PA    3P    3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# DAL17-18  51.2  4.75  98.6  21.1  2.846  58.7  44.2  142.8  255  10.2  18.1
#
#           BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# DAL17-18  1.1  3.2  65.5  150.2  982  72.3  4.291  157.4  25.5  6.862  34.1
#
#             G   GS     MP OBPM   ORB ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# DAL17-18  649  378  16206   -2  18.1   38  999  135.9  37.3  191.2  12.6
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# DAL17-18  12.6  22.2  102.1  83.3  92.2  5.089  176.1    7           2
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# DAL17-18           1           0            0            1            1
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# DAL17-18            0            0            0            1            1
#
# ...

# %% [markdown]
# ### MEM

# %%
MEM_17_18 = season_17_18_cluster[season_17_18_cluster['Tm']=='MEM']
MEM_17_18.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA  AST  AST%  Age  BLK  BLK%  \
# Name
# Mario Chalmers   4.1  0.456   9.0  1.9  0.277  6.8  7.0  21.5   31  0.5   0.9
# Tyreke Evans     7.9  0.482  16.5  3.6  0.399  9.0  8.5  31.2   28  0.5   1.0
# Andrew Harrison  5.1  0.467  10.9  1.8  0.331  5.4  6.7  21.3   23  1.0   1.8
# Ben McLemore     4.7  0.477   9.9  2.5  0.346  7.4  2.4   7.5   24  0.7   1.3
# Dillon Brooks    5.3  0.484  10.9  2.0  0.356  5.7  2.9   9.3   22  0.4   0.7
#
#                  BPM  DBPM  DRB  DRB%  DRtg    FG    FG%   FGA   FT    FT%  \
# Name
# Mario Chalmers  -2.7  -0.5  5.1  12.0   110   6.0  0.379  15.8  4.2  0.855
# Tyreke Evans     3.6  -0.8  7.0  16.3   111  11.5  0.452  25.5  5.2  0.785
# Andrew Harrison -2.5  -1.5  4.1   9.7   113   6.9  0.422  16.4  4.7  0.780
# Ben McLemore    -3.6  -1.4  4.9  11.4   112   7.3  0.421  17.3  2.5  0.828
# Dillon Brooks   -3.1  -1.3  4.5  10.5   113   7.3  0.440  16.6  2.7  0.747
#
# ...

# %%
MEM_17_18.drop(columns=['Pos'], inplace=True)
MEM_17_18_sum = pd.DataFrame(MEM_17_18.sum(axis=0))
MEM_17_18_sum.loc['Tm', 0]= 'MEM17-18'
MEM_17_18_sum = MEM_17_18_sum.T.set_index('Tm')
MEM_17_18_sum
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age  BLK  BLK%  \
# Tm
# MEM17-18  54.1  4.399  110.3  16.5  2.736  48.2  40.8  134.9  232  9.6  17.8
#
#            BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# MEM17-18 -12.2 -3.9  62.9  147.4  998  70.7  4.045  158.6  32.5  6.984  41.5
#
#             G   GS     MP OBPM   ORB  ORB% ORtg    PER    PF    PTS   STL  \
# Tm
# MEM17-18  575  348  14349 -8.2  18.9  42.1  947  122.2  48.1  190.6  13.5
#
#           STL%   TOV   TOV%   TRB  TRB%    TS%   USG% VORP c_cluster_0  \
# Tm
# MEM17-18  13.5  27.4  120.3  81.5  93.3  4.854  180.9  2.9           1
#
#          c_cluster_1 c_cluster_2 pf_cluster_0 pf_cluster_1 pf_cluster_2  \
# Tm
# MEM17-18           0           1            0            0            1
#
#          pf_cluster_3 pf_cluster_4 pg_cluster_0 pg_cluster_1 pg_cluster_2  \
# Tm
# MEM17-18            1            0            0            2            1
#
# ...

# %% [markdown]
# ## Combining all the teams

# %%
all_teams = [TOR_17_18_sum, BOS_17_18_sum, PHI_17_18_sum, NYK_17_18_sum, BRK_17_18_sum, CLE_17_18_sum, IND_17_18_sum,
             MIL_17_18_sum, DET_17_18_sum, CHI_17_18_sum, MIA_17_18_sum, WAS_17_18_sum, CHO_17_18_sum, ORL_17_18_sum,
             POR_17_18_sum, OKC_17_18_sum, UTA_17_18_sum, MIN_17_18_sum, DEN_17_18_sum, GSW_17_18_sum, LAC_17_18_sum,
             LAL_17_18_sum, SAC_17_18_sum, PHO_17_18_sum, HOU_17_18_sum, NOP_17_18_sum, SAS_17_18_sum, DAL_17_18_sum,
             MEM_17_18_sum, ATL_17_18_sum]
sum_all_teams = pd.concat(all_teams)

# %%
sum_all_teams.head() #checking data
# Out:
#             2P    2P%    2PA    3P    3P%   3PA   AST   AST%  Age   BLK  BLK%  \
# Tm
# TOR17-18  56.8  4.947  103.2  18.4  3.345  50.4    45  134.1  225  11.7    19
# BOS17-18  48.9  4.244  100.7  22.2  3.179  59.2  40.6  132.4  224   7.4  12.5
# PHI17-18  55.1  4.715  103.2    18  2.702  49.2    49  152.2  228  10.3  17.6
# NYK17-18    62  4.373  123.6  13.9   2.76  39.3  41.9  124.4  242  11.3  19.6
# BRK17-18  45.2   4.39     91  24.1  3.088    68  45.5  151.4  219     9  13.7
#
#            BPM DBPM   DRB   DRB% DRtg    FG    FG%    FGA    FT    FT%   FTA  \
# Tm
# TOR17-18  19.7  8.2  65.9  146.4  952    75  4.463  153.4  30.7  6.787  39.4
# BOS17-18   5.4  7.8  64.3  138.8  940  71.1  3.928  159.8  29.2  6.814  37.5
# PHI17-18  10.3  9.1  68.6  148.1  943    73  4.326  152.6  30.9  6.807  41.3
# NYK17-18  -5.3 -1.4  67.3  150.2  996  76.1  4.169  162.8  29.6  7.319  36.8
# BRK17-18  -3.6 -3.6  61.3  135.2  995  69.2  3.965  158.9  32.6  7.088  41.9
#
# ...

# %%
# dividing the percentages by 9 players to reflect correctly.

sum_all_teams['2P%'] = sum_all_teams['2P%']/9
sum_all_teams['3P%'] = sum_all_teams['3P%']/9
sum_all_teams['AST%'] = sum_all_teams['AST%']/9
sum_all_teams['BLK%'] = sum_all_teams['BLK%']/9
sum_all_teams['DRB%'] = sum_all_teams['DRB%']/9
sum_all_teams['FT%']= sum_all_teams['FT%']/9
sum_all_teams['ORB%'] = sum_all_teams['ORB%']/9
sum_all_teams['STL%'] = sum_all_teams['STL%']/9
sum_all_teams['TOV%'] = sum_all_teams['TOV%']/9
sum_all_teams['TRB%'] = sum_all_teams['TRB%']/9
sum_all_teams['TS%'] = sum_all_teams['TS%']/9
sum_all_teams['USG%'] = sum_all_teams['USG%']/9
sum_all_teams['Age'] = sum_all_teams['Age']/9

# %%
sum_all_teams.head() # checking
# Out:
#             2P       2P%    2PA    3P       3P%   3PA   AST     AST%      Age  \
# Tm
# TOR17-18  56.8  0.549667  103.2  18.4  0.371667  50.4    45     14.9       25
# BOS17-18  48.9  0.471556  100.7  22.2  0.353222  59.2  40.6  14.7111  24.8889
# PHI17-18  55.1  0.523889  103.2    18  0.300222  49.2    49  16.9111  25.3333
# NYK17-18    62  0.485889  123.6  13.9  0.306667  39.3  41.9  13.8222  26.8889
# BRK17-18  45.2  0.487778     91  24.1  0.343111    68  45.5  16.8222  24.3333
#
#            BLK     BLK%   BPM DBPM   DRB     DRB% DRtg    FG    FG%    FGA  \
# Tm
# TOR17-18  11.7  2.11111  19.7  8.2  65.9  16.2667  952    75  4.463  153.4
# BOS17-18   7.4  1.38889   5.4  7.8  64.3  15.4222  940  71.1  3.928  159.8
# PHI17-18  10.3  1.95556  10.3  9.1  68.6  16.4556  943    73  4.326  152.6
# NYK17-18  11.3  2.17778  -5.3 -1.4  67.3  16.6889  996  76.1  4.169  162.8
# BRK17-18     9  1.52222  -3.6 -3.6  61.3  15.0222  995  69.2  3.965  158.9
#
# ...

# %%
## puting in teams that made playoffs 17-18

# %%
sum_all_teams.loc['TOR17-18', 'Playoffs'] = 1
sum_all_teams.loc['BOS17-18', 'Playoffs'] = 1
sum_all_teams.loc['PHI17-18', 'Playoffs'] = 1
sum_all_teams.loc['CLE17-18', 'Playoffs'] = 1
sum_all_teams.loc['IND17-18', 'Playoffs'] = 1
sum_all_teams.loc['MIA17-18', 'Playoffs'] = 1
sum_all_teams.loc['MIL17-18', 'Playoffs'] = 1
sum_all_teams.loc['WAS17-18', 'Playoffs'] = 1
sum_all_teams.loc['HOU17-18', 'Playoffs'] = 1
sum_all_teams.loc['GSW17-18', 'Playoffs'] = 1
sum_all_teams.loc['POR17-18', 'Playoffs'] = 1
sum_all_teams.loc['OKC17-18', 'Playoffs'] = 1
sum_all_teams.loc['UTA17-18', 'Playoffs'] = 1
sum_all_teams.loc['NOP17-18', 'Playoffs'] = 1
sum_all_teams.loc['SAS17-18', 'Playoffs'] = 1
sum_all_teams.loc['MIN17-18', 'Playoffs'] = 1

# %%
# Filling the rest of the teams with 0 that didn't make playoffs
sum_all_teams.fillna(0, inplace=True)

# %%
sum_all_teams.head()
# Out:
#             2P       2P%    2PA    3P       3P%   3PA   AST       AST%  \
# Tm
# TOR17-18  56.8  0.549667  103.2  18.4  0.371667  50.4  45.0  14.900000
# BOS17-18  48.9  0.471556  100.7  22.2  0.353222  59.2  40.6  14.711111
# PHI17-18  55.1  0.523889  103.2  18.0  0.300222  49.2  49.0  16.911111
# NYK17-18  62.0  0.485889  123.6  13.9  0.306667  39.3  41.9  13.822222
# BRK17-18  45.2  0.487778   91.0  24.1  0.343111  68.0  45.5  16.822222
#
#                 Age   BLK      BLK%   BPM  DBPM   DRB       DRB%  DRtg    FG  \
# Tm
# TOR17-18  25.000000  11.7  2.111111  19.7   8.2  65.9  16.266667   952  75.0
# BOS17-18  24.888889   7.4  1.388889   5.4   7.8  64.3  15.422222   940  71.1
# PHI17-18  25.333333  10.3  1.955556  10.3   9.1  68.6  16.455556   943  73.0
# NYK17-18  26.888889  11.3  2.177778  -5.3  -1.4  67.3  16.688889   996  76.1
# BRK17-18  24.333333   9.0  1.522222  -3.6  -3.6  61.3  15.022222   995  69.2
#
# ...

# %%
## looking at all the playoffs teams to see which cluster is most prominent
playoff_teams=sum_all_teams[sum_all_teams['Playoffs']==1]
playoff_teams.head()
# Out:
#             2P       2P%    2PA    3P       3P%   3PA   AST       AST%  \
# Tm
# TOR17-18  56.8  0.549667  103.2  18.4  0.371667  50.4  45.0  14.900000
# BOS17-18  48.9  0.471556  100.7  22.2  0.353222  59.2  40.6  14.711111
# PHI17-18  55.1  0.523889  103.2  18.0  0.300222  49.2  49.0  16.911111
# CLE17-18  44.3  0.534222   81.3  23.4  0.340000  60.6  36.8  12.900000
# IND17-18  58.3  0.506000  114.4  17.2  0.365556  46.7  43.0  14.166667
#
#                 Age   BLK      BLK%   BPM  DBPM   DRB       DRB%  DRtg    FG  \
# Tm
# TOR17-18  25.000000  11.7  2.111111  19.7   8.2  65.9  16.266667   952  75.0
# BOS17-18  24.888889   7.4  1.388889   5.4   7.8  64.3  15.422222   940  71.1
# PHI17-18  25.333333  10.3  1.955556  10.3   9.1  68.6  16.455556   943  73.0
# CLE17-18  30.222222   5.3  1.055556  -1.6  -9.5  64.1  16.022222  1010  67.8
# IND17-18  25.777778   7.5  1.466667   0.4  -0.2  60.9  15.177778   976  75.5
#
# ...

# %%
playoff_teams.columns
# Out:
# Index(['2P', '2P%', '2PA', '3P', '3P%', '3PA', 'AST', 'AST%', 'Age', 'BLK',
#        'BLK%', 'BPM', 'DBPM', 'DRB', 'DRB%', 'DRtg', 'FG', 'FG%', 'FGA', 'FT',
#        'FT%', 'FTA', 'G', 'GS', 'MP', 'OBPM', 'ORB', 'ORB%', 'ORtg', 'PER',
#        'PF', 'PTS', 'STL', 'STL%', 'TOV', 'TOV%', 'TRB', 'TRB%', 'TS%', 'USG%',
#        'VORP', 'c_cluster_0', 'c_cluster_1', 'c_cluster_2', 'pf_cluster_0',
#        'pf_cluster_1', 'pf_cluster_2', 'pf_cluster_3', 'pf_cluster_4',
#        'pg_cluster_0', 'pg_cluster_1', 'pg_cluster_2', 'sf_cluster_0',
#        'sf_cluster_1', 'sf_cluster_2', 'sg_cluster_0', 'sg_cluster_1',
#        'Playoffs'],
#       dtype='object')

# %%
### looking at the clusters
cluster =['c_cluster_0', 'c_cluster_1', 'c_cluster_2', 'pf_cluster_0',
       'pf_cluster_1', 'pf_cluster_2', 'pf_cluster_3', 'pf_cluster_4',
       'pg_cluster_0', 'pg_cluster_1', 'pg_cluster_2', 'sf_cluster_0',
       'sf_cluster_1', 'sf_cluster_2', 'sg_cluster_0', 'sg_cluster_1']

X = playoff_teams[cluster]

# %%
X.sum()
## interesting to see that playoff teams have a lot of C0,PF2,PG1,SG0
# Out:
# c_cluster_0     15.0
# c_cluster_1      5.0
# c_cluster_2     11.0
# pf_cluster_0     4.0
# pf_cluster_1     4.0
# pf_cluster_2    17.0
# pf_cluster_3     1.0
# pf_cluster_4     4.0
# pg_cluster_0     3.0
# pg_cluster_1    18.0
# pg_cluster_2     8.0
# sf_cluster_0     9.0
# sf_cluster_1     4.0
# sf_cluster_2     9.0
# sg_cluster_0    18.0
# sg_cluster_1    14.0
# dtype: float64

# %%
X.mean()
# Out:
# c_cluster_0     0.9375
# c_cluster_1     0.3125
# c_cluster_2     0.6875
# pf_cluster_0    0.2500
# pf_cluster_1    0.2500
# pf_cluster_2    1.0625
# pf_cluster_3    0.0625
# pf_cluster_4    0.2500
# pg_cluster_0    0.1875
# pg_cluster_1    1.1250
# pg_cluster_2    0.5000
# sf_cluster_0    0.5625
# sf_cluster_1    0.2500
# sf_cluster_2    0.5625
# sg_cluster_0    1.1250
# sg_cluster_1    0.8750
# dtype: float64

# %%
## looking at non playoff teams
non_playoff_teams = sum_all_teams[sum_all_teams['Playoffs']==0]

y = non_playoff_teams[cluster]

# %%
y.sum()
# Out:
# c_cluster_0     13.0
# c_cluster_1      5.0
# c_cluster_2      9.0
# pf_cluster_0     3.0
# pf_cluster_1    13.0
# pf_cluster_2     6.0
# pf_cluster_3     2.0
# pf_cluster_4     0.0
# pg_cluster_0     1.0
# pg_cluster_1    19.0
# pg_cluster_2     6.0
# sf_cluster_0     7.0
# sf_cluster_1     9.0
# sf_cluster_2     2.0
# sg_cluster_0    20.0
# sg_cluster_1    11.0
# dtype: float64

# %%
y.mean()
# Out:
# c_cluster_0     0.928571
# c_cluster_1     0.357143
# c_cluster_2     0.642857
# pf_cluster_0    0.214286
# pf_cluster_1    0.928571
# pf_cluster_2    0.428571
# pf_cluster_3    0.142857
# pf_cluster_4    0.000000
# pg_cluster_0    0.071429
# pg_cluster_1    1.357143
# pg_cluster_2    0.428571
# sf_cluster_0    0.500000
# sf_cluster_1    0.642857
# sf_cluster_2    0.142857
# sg_cluster_0    1.428571
# sg_cluster_1    0.785714
# dtype: float64

# %%
pd.DataFrame(X.mean() - y.mean()).sort_values(0, ascending=False)
## based off looking at the mean it seems that PF2, SF2 are most important in making playoffs
# Out:
#                      0
# pf_cluster_2  0.633929
# sf_cluster_2  0.419643
# pf_cluster_4  0.250000
# pg_cluster_0  0.116071
# sg_cluster_1  0.089286
# pg_cluster_2  0.071429
# sf_cluster_0  0.062500
# c_cluster_2   0.044643
# pf_cluster_0  0.035714
# c_cluster_0   0.008929
# c_cluster_1  -0.044643
# pf_cluster_3 -0.080357
# pg_cluster_1 -0.232143
# sg_cluster_0 -0.303571
# sf_cluster_1 -0.392857
# pf_cluster_1 -0.678571

# %%
pd.DataFrame(X.sum() -y.sum()).sort_values(0, ascending=False)
## based off the sum it seems that PF2 and SF2 followed by PF4 and SG2 are most important to make playoffs
# Out:
#                  0
# pf_cluster_2  11.0
# sf_cluster_2   7.0
# pf_cluster_4   4.0
# sg_cluster_1   3.0
# c_cluster_0    2.0
# c_cluster_2    2.0
# pg_cluster_0   2.0
# pg_cluster_2   2.0
# sf_cluster_0   2.0
# pf_cluster_0   1.0
# c_cluster_1    0.0
# pf_cluster_3  -1.0
# pg_cluster_1  -1.0
# sg_cluster_0  -2.0
# sf_cluster_1  -5.0
# pf_cluster_1  -9.0

# %%
### Lets look at the players that are valuable in making playoffs

# %%
all_teams = [TOR_17_18, BOS_17_18, PHI_17_18, NYK_17_18, BRK_17_18, CLE_17_18, IND_17_18,
             MIL_17_18, DET_17_18, CHI_17_18, MIA_17_18, WAS_17_18, CHO_17_18, ORL_17_18,
             POR_17_18, OKC_17_18, UTA_17_18, MIN_17_18, DEN_17_18, GSW_17_18, LAC_17_18,
             LAL_17_18, SAC_17_18, PHO_17_18, HOU_17_18, NOP_17_18, SAS_17_18, DAL_17_18,
             MEM_17_18, ATL_17_18]
players_all_teams = pd.concat(all_teams)

# %%
players_all_teams[players_all_teams['pf_cluster_2']==1].head()
# Out:
#                    2P    2P%   2PA   3P    3P%   3PA  AST  AST%  Age  BLK  \
# Name
# Serge Ibaka       6.4  0.559  11.5  2.5  0.360   7.0  1.5   4.4   28  2.3
# Pascal Siakam     6.6  0.612  10.7  0.9  0.220   3.9  4.7  13.5   23  1.2
# Jeff Green        6.5  0.540  12.0  1.4  0.312   4.6  2.7   8.0   31  0.9
# Thaddeus Young    7.0  0.531  13.1  1.1  0.320   3.5  2.9   8.5   29  0.7
# Anthony Tolliver  1.7  0.561   3.0  4.5  0.436  10.4  2.6   7.5   32  0.6
#
#                   BLK%  BPM  DBPM  DRB  DRB%  DRtg   FG    FG%   FGA   FT  \
# Name
# Serge Ibaka        3.8 -0.2   0.6  9.4  21.0   105  8.9  0.483  18.5  2.2
# Pascal Siakam      2.0  2.1   2.2  8.4  18.6   105  7.4  0.508  14.6  1.6
# Jeff Green         1.6 -1.9  -1.7  5.0  11.2   114  7.9  0.477  16.6  5.4
# Thaddeus Young     1.2  1.5   1.4  6.3  14.1   107  8.1  0.487  16.6  1.1
# Anthony Tolliver   1.1  1.5  -0.8  5.4  12.3   110  6.2  0.464  13.4  3.0
#
# ...

# %%
## pf cluster 2

# %% [markdown]
# PF2 Blking 3p shooters hybrid, High STL
# <br/> Stretch 4's Better D(Stl) - Draymond Green, Serge Ibaka, Markieff Morris, Pascal Siakam

# %%
## from this it seems in order to make the playoffs it's best to have a stretch 4 with really good defense.
## PF that can shoot and play some defense. Which really is what the modern NBA is looking for .

# %%
sum_all_teams.to_csv('./17_18_teams')
