# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url =('https://www.basketball-reference.com/teams/GSW/2018.html')

# %%
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.content
# Out:
# b'\n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/bbr/build" itemscope itemtype="https://schema.org/WebSite" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://d2p3bygnnzw9w3.cloudfront.net/req/201808291" />\n\n<!-- no:cookie fast load the css.           -->\n<link rel="preconnect" href="https://d2p3bygnnzw9w3.cloudfront.net" crossorigin>\n<link rel="preconnect" href="https://d2cwpp38twqe55.cloudfront.net" crossorigin>\n <style>html,body{margin:0;padding:0;font:14px/1.25 "Helvetica Neue",helvetica,arial,sans-serif;color:#000}body{position:relative;background:#c9cbcd;z-index:0;-webkit-text-size-adjust:none;-moz-text-size-adjust:none;-ms-text-size-adjust:none}a img{border:0}ul,li,ol{margin:0;padding:0;list-style-type:none}table th,table td{border:0}iframe{max-wi
# ...

# %%
soup = BeautifulSoup(res.content, 'html.parser')

# %%
soup = BeautifulSoup(exclude_encodings= "<!--|-->",res.content, 'lxml')
# Out:
#   File "<ipython-input-27-0032612c5d29>", line 1
#     soup = BeautifulSoup(exclude_encodings= "<!--|-->",res.content, 'lxml')
#                                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
soup=BeautifulSoup(res.sub("<!--|-->","", html))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4161e6c51620> in <module>()
# ----> 1 soup=BeautifulSoup(res.sub("<!--|-->","", html))
#
# AttributeError: 'Response' object has no attribute 'sub'

# %%
from bs4 import BeautifulSoup
import requests
comm = res.compile("<!--|-->")

html = requests.get("https://www.basketball-reference.com/teams/GSW/2018.html").content
cleaned_soup = BeautifulSoup(re.sub("<!--|-->","", html))


tableStats = cleaned_soup.find('table', {'id':'team_stats'})

print(tableStats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-76d25da86716> in <module>()
#       1 from bs4 import BeautifulSoup
#       2 import requests
# ----> 3 comm = re.compile("<!--|-->")
#       4
#       5 html = requests.get("https://www.basketball-reference.com/teams/GSW/2018.html").content
#
# NameError: name 're' is not defined
