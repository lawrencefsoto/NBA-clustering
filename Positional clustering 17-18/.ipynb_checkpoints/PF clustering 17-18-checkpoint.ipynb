# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from collections import Counter

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../clean_season_17_18')

# %%
df.shape
# Out:
# (372, 44)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 44 columns):
# Name    372 non-null object
# 2P      372 non-null float64
# 2P%     372 non-null float64
# 2PA     372 non-null float64
# 3P      372 non-null float64
# 3P%     372 non-null float64
# 3PA     372 non-null float64
# AST     372 non-null float64
# Age     372 non-null float64
# BLK     372 non-null float64
# DRB     372 non-null float64
# DRtg    372 non-null float64
# FG      372 non-null float64
# FG%     372 non-null float64
# FGA     372 non-null float64
# FT      372 non-null float64
# FT%     372 non-null float64
# FTA     372 non-null float64
# G       372 non-null float64
# GS      372 non-null float64
# MP      372 non-null float64
# ORB     372 non-null float64
# ORtg    372 non-null float64
# PF      372 non-null float64
# PTS     372 non-null float64
# Pos     372 non-null object
# STL     372 non-null float64
# TOV     372 non-null float64
# TRB     372 non-null float64
# Tm      372 non-null object
# AST%    372 non-null float64
# BLK%    372 non-null float64
# BPM     372 non-null float64
# DBPM    372 non-null float64
# DRB%    372 non-null float64
# OBPM    372 non-null float64
# ORB%    372 non-null float64
# PER     372 non-null float64
# STL%    372 non-null float64
# TOV%    372 non-null float64
# TRB%    372 non-null float64
# TS%     372 non-null float64
# USG%    372 non-null float64
# VORP    372 non-null float64
# dtypes: float64(41), object(3)
# memory usage: 128.0+ KB

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 700) # want to see more rows and columns

df.set_index('Name', inplace=True)

# %%
df.head()
# Out:
#                 2P    2P%   2PA   3P    3P%   3PA  AST   Age  BLK  DRB   DRtg  \
# Name
# Alex Abrines   1.4  0.443   3.1  3.7  0.380   9.7  1.2  24.0  0.4  3.9  110.0
# Quincy Acy     1.0  0.384   2.6  3.6  0.349  10.4  2.0  27.0  1.0  7.8  110.0
# Steven Adams   8.9  0.631  14.2  0.0  0.000   0.0  1.8  24.0  1.6  6.0  107.0
# Bam Adebayo    6.4  0.523  12.2  0.0  0.000   0.3  3.7  20.0  1.5  9.7  105.0
# Arron Afflalo  2.7  0.413   6.6  1.9  0.386   5.0  2.2  32.0  0.6  4.5  115.0
#
#                 FG    FG%   FGA   FT    FT%  FTA     G    GS      MP  ORB  \
# Name
# Alex Abrines   5.0  0.395  12.7  1.7  0.848  2.0  75.0   8.0  1134.0  1.1
# Quincy Acy     4.6  0.356  13.0  1.8  0.817  2.1  70.0   8.0  1359.0  1.4
# Steven Adams   8.9  0.629  14.2  3.2  0.559  5.7  76.0  76.0  2487.0  7.7
# Bam Adebayo    6.4  0.512  12.5  4.7  0.721  6.6  69.0  19.0  1368.0  4.3
# Arron Afflalo  4.7  0.401  11.6  1.6  0.846  1.9  53.0   3.0   682.0  0.3
#
#                 ORtg   PF   PTS Pos  STL  TOV   TRB   Tm  AST%  BLK%  BPM  \
# Name
# Alex Abrines   116.0  5.4  15.4  SG  1.7  1.1   5.0  OKC   3.4   0.6 -2.2
# Quincy Acy      99.0  5.3  14.7  PF  1.2  2.1   9.2  BRK   6.0   1.6 -2.2
# Steven Adams   125.0  4.3  21.1   C  1.8  2.6  13.7  OKC   5.5   2.8  3.3
# Bam Adebayo    116.0  5.1  17.5   C  1.2  2.4  14.0  MIA  11.0   2.5  0.2
# Arron Afflalo   98.0  4.0  12.8  SG  0.3  1.5   4.7  ORL   6.2   1.1 -5.8
#
#                DBPM  DRB%  OBPM  ORB%   PER  STL%  TOV%  TRB%    TS%  USG%  \
# Name
# Alex Abrines   -1.7   8.9  -0.5   2.5   9.0   1.7   7.4   5.6  0.567  12.7
# Quincy Acy     -0.2  17.0  -2.0   3.1   8.2   1.2  13.3  10.0  0.525  14.4
# Steven Adams    1.1  13.9   2.2  16.6  20.6   1.8  13.2  15.3  0.630  16.7
# Bam Adebayo     1.8  21.6  -1.6   9.7  15.7   1.2  13.6  15.6  0.570  15.9
# Arron Afflalo  -1.8  10.1  -4.1   0.6   5.8   0.3  10.8   5.3  0.516  12.5
#
#                VORP
# Name
# Alex Abrines   -0.1
# Quincy Acy     -0.1
# Steven Adams    3.3
# Bam Adebayo     0.8
# Arron Afflalo  -0.7

# %%
df = df[df['G']>=40]

# %%
pf = df[df['Pos']=='PF']

# %%
pf = pf.reindex(sorted(pf.columns), axis=1)

# %%
X = pf.drop(columns=['G','GS','MP','Age','Pos','Tm']) ## took out columns that don't matter to the model
ss=StandardScaler()
pf_scaled=ss.fit_transform(X)

# %%
cluster_range = range( 1, 6 )
cluster_errors = []

for num_clusters in cluster_range:
    clusters = KMeans(num_clusters)
    clusters.fit(pf_scaled)
    cluster_errors.append(clusters.inertia_)

clusters_df = pd.DataFrame({ "num_clusters":cluster_range, "cluster_errors": cluster_errors })

plt.figure(figsize=(8,4))
plt.plot( clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" );

# %%
#maybe 3 or 4 clusters

# %%
from sklearn import cluster, metrics, datasets

import seaborn as sns

# %%
def kmeans(reduced_data, n_clusters):

    kmeans = cluster.KMeans(n_clusters=n_clusters, random_state=42)
    kmeans = kmeans.fit(reduced_data)
    labels = kmeans.labels_
    centroids = kmeans.cluster_centers_
    inertia = kmeans.inertia_
    sil_score = metrics.silhouette_score(reduced_data, kmeans.labels_, metric='euclidean')

    data_dictionary = {
        "labels": labels,
        "centroids": centroids,
        "inertia" : inertia,
        "silhouette_score": sil_score
    }

    return data_dictionary

# %%
kmeans(pf_scaled,5)
# Out:
# {'labels': array([0, 2, 2, 4, 1, 1, 1, 0, 2, 2, 3, 2, 3, 4, 2, 3, 0, 4, 1, 2, 1, 2,
#         2, 3, 2, 1, 1, 0, 2, 2, 4, 2, 2, 1, 2, 1, 1, 0, 1, 1, 2, 2, 1, 3,
#         1, 2, 0, 2, 0, 1, 1, 1, 1, 2, 2, 0, 2, 0, 3, 2, 2, 2], dtype=int32),
#  'centroids': array([[-1.40744364, -1.53690639, -1.33074876,  0.13358235,  0.30614547,
#           0.16607563, -0.57296696, -0.6278238 , -0.41204292, -0.40100036,
#          -0.92523982, -0.24394764, -0.98814086, -0.99911202,  0.6941137 ,
#          -1.43490745, -1.47353375, -1.26884764, -1.02800046, -0.41274322,
#          -1.08506764, -0.9780081 , -0.65842139, -0.67750545, -0.87928058,
#          -1.45779634,  0.23773144, -1.33774235, -0.38633832, -0.38633832,
#          -0.85570312,  0.27397681, -1.00208526, -1.01764166, -1.01035597,
#          -1.28673536, -0.66353884],
#         [ 0.55594024, -0.34364907,  0.74708702,  0.48324907,  0.33917988,
#           0.49552057,  0.01814409,  0.09115774, -0.19554579, -0.18143087,
#          -0.21777716, -0.64602891,  0.21852851,  0.22417158,  0.23882109,
#           0.78456661, -0.20610154,  1.02653858,  0.50722026,  0.42227062,
#           0.4698289 ,  0.1637277 , -0.05543577, -0.09534671, -0.34648139,
#           0.40339032, -0.63101168,  0.80477393, -0.29882745, -0.29882745,
#           0.32858096, -0.48044985,  0.13592848,  0.09930835, -0.26427058,
#           0.90264898, -0.25457084],
#         [-0.26759022,  0.54081588, -0.36751588, -0.02186948,  0.0091111 ,
#          -0.00646348, -0.05216427, -0.12542968, -0.06737949, -0.07198392,
#           0.11852644,  0.18818818, -0.33284841, -0.33380851, -0.12620481,
#          -0.29329893,  0.2206457 , -0.37979266, -0.34178117, -0.03195953,
#          -0.32655721,  0.01633517, -0.15673736, -0.14272859,  0.28515592,
#          -0.2162984 ,  0.26037733, -0.31456287,  0.25174095,  0.25174095,
#          -0.21537297,  0.02898752, -0.30900357, -0.29390251,  0.31122053,
#          -0.37662045,  0.01243674],
#         [ 0.20923158,  0.48058736,  0.10824272, -1.44491311, -1.67316605,
#          -1.52002766, -0.22402916, -0.25447686,  0.58384387,  0.59128484,
#          -0.18973748,  0.7876548 ,  1.55296287,  1.5644428 , -0.69155946,
#          -0.36223028,  1.06133068, -0.69771559, -0.26648224, -0.90028706,
#          -0.11574912, -0.74754171,  1.97964067,  1.99727794,  0.38708273,
#           0.08531756,  1.18456384, -0.56845223, -0.18631347, -0.18631347,
#          -0.02145374,  0.78596614,  1.96719096,  1.96089169,  0.06644103,
#          -0.56169185, -0.33775077],
#         [ 2.02360864,  0.90347991,  1.76690326, -0.17112721,  0.2376679 ,
#          -0.28307446,  1.86959765,  2.16804448,  1.35240868,  1.28166198,
#           2.60560279,  1.09835396,  0.99079691,  0.9788689 , -0.81033145,
#           2.07445576,  1.27187623,  1.65576106,  2.56636551,  0.57863212,
#           2.54177839,  2.48296132, -0.25894342, -0.15041578,  1.17469893,
#           2.68867401, -1.09954729,  2.20713391,  0.92007398,  0.92007398,
#           1.82497932,  0.18545529,  0.62349951,  0.73835935,  1.41772866,
#           2.02964977,  3.06742768]]),
#  'inertia': 1219.9033422165514,
#  'silhouette_score': 0.1540942023880002}

# %%
def find_best_cluster(data,a,b):

    scores = []
    for i in range(a,b):
        i_clusters = kmeans(data, i)
        sil_score_i = i_clusters['silhouette_score']
        scores.append(sil_score_i)

    sns.set_context('poster', font_scale=1)
    plt.plot(range(a,b), scores)
    plt.title("""Measuring Silhouette Score to Find Best Cluster""")
    print ("best silhouette score:", np.max(scores))

# %%
find_best_cluster(pf_scaled,2,9)
# Out:
# best silhouette score: 0.15807411715249897

# %%
#5 clusters seem like to be a good split or try 2

# %%
pfk= KMeans(n_clusters=5, random_state=42)
pfk.fit(pf_scaled)
pf['pf_cluster'] = pfk.labels_
Counter(pfk.labels_)
# Out:
# Counter({0: 9, 2: 25, 4: 4, 1: 18, 3: 6})

# %%
pf[pf['pf_cluster']==1]
# Out:
#                       2P    2P%   2PA   3P    3P%   3PA  AST  AST%   Age  BLK  \
# Trey Lyles          116.0  17.9  4.0  25.8  PF  1.1   1.1  2.2   9.0  12.4
# Lauri Markkanen     107.0  15.6  2.5  25.0  PF  0.9   0.9  2.0   8.2  12.3
# Nikola Mirotic      111.0  18.7  3.5  27.7  PF  1.4   1.4  2.0   7.7  13.1
# Marcus Morris       106.0  14.5  3.5  25.4  PF  1.2   1.2  2.2   8.7  10.0
# Bobby Portis        108.0  19.7  3.9  28.6  PF  1.5   1.5  3.1  10.5  14.8
# Kristaps Porzingis  105.0  20.4  4.5  34.7  PF  1.1   1.1  3.0   8.4  10.1
# Zach Randolph       101.0  17.3  4.0  28.7  PF  1.4   1.4  3.9  12.5  13.3
# Dario Saric         113.0  15.8  3.3  23.8  PF  1.1   1.1  3.1  13.1  10.8
#
#                     TRB%    TS%   Tm  USG%  VORP  pf_cluster
# Name
# Carmelo Anthony     10.0  0.503  OKC  23.2  -1.1           1
# Harrison Barnes      9.9  0.539  DAL  25.2  -0.1           1
# Michael Beasley     13.9  0.556  NYK  26.9   0.2           1
# Rudy Gay            13.1  0.545  SAS  24.6   0.7           1
# Aaron Gordon        13.2  0.530  ORL  24.7   1.0           1
# Blake Griffin       12.0  0.544  TOT  28.9   2.4           1
# Tobias Harris        9.0  0.565  TOT  23.3   1.8           1
# Frank Kaminsky       8.5  0.545  CHO  20.5   0.5           1
# Kyle Kuzma          10.7  0.549  LAL  22.5   0.4           1
# Skal Labissiere     13.2  0.513  SAC  21.1  -0.2           1
# Trey Lyles          14.0  0.591  DEN  21.1   0.4           1
# Lauri Markkanen     13.5  0.552  CHI  21.9   0.1           1
# Nikola Mirotic      14.6  0.577  TOT  23.4   1.0           1
# Marcus Morris       10.9  0.541  BOS  23.0   0.1           1
# Bobby Portis        16.2  0.548  CHI  26.0   1.0           1
# Kristaps Porzingis  11.3  0.539  NYK  31.0   0.5           1
# Zach Randolph       15.0  0.529  SAC  27.6   0.1           1
# Dario Saric         12.1  0.582  PHI  20.9   2.0           1

# %%
pf_corr = pf.drop(columns=['Age','G','GS','MP','Pos','Tm'])

# %%
import seaborn as sns
corr=pf_corr.corr()

corr = corr.sort_values('pf_cluster',ascending=False)

plt.figure(figsize=(9,10))
sns.barplot(corr.pf_cluster[1:], corr.index[1:], color='b')
plt.show()

# %%
pf_p= pf[['VORP','pf_cluster']]
pf_p.groupby(['pf_cluster']).mean().plot(kind='barh', figsize=(6,6))

# %%
test= pf[['3P','pf_cluster']]
test.groupby(['pf_cluster']).mean().plot(kind='barh', figsize=(6,6))

# %%
##pf0 low usage don't do much
##pf1 makes most 3's, Defensive liability
##pf2 BLKing 3p shooters hybrid
##pf3 gets most rebounds, most PF,
##pf4 Defintely the most VORP, high Per, 2P, High BLK, High AST, OPBM

# %%
pf[pf['pf_cluster']==3]
# Out:
#                  2P    2P%   2PA   3P    3P%  3PA  AST  AST%   Age  BLK  BLK%  \
# Name
# Trevor Booker   7.1  0.545  13.0  0.3  0.242  1.4  3.4  10.8  30.0  0.9   1.5
# John Collins    8.2  0.598  13.6  0.4  0.340  1.3  2.7   8.9  20.0  2.2   3.8
# Cheick Diallo   8.4  0.580  14.5  0.0  0.000  0.0  1.6   4.7  21.0  1.7   2.9
# JaMychal Green  5.9  0.499  11.8  1.4  0.339  4.2  2.6   8.3  27.0  0.8   1.5
# Eric Moreland   4.1  0.541   7.6  0.0  0.000  0.0  4.8  13.3  26.0  3.2   5.6
# Noah Vonleh     4.7  0.500   9.5  1.1  0.303  3.7  1.9   5.7  22.0  1.0   1.6
#
#                 BPM  DBPM   DRB  DRB%   DRtg   FG    FG%   FGA   FT    FT%  \
# Name
# Trevor Booker  -0.5   0.5   8.4  18.6  108.0  7.4  0.516  14.4  2.8  0.710
# John Collins    1.7   1.9  10.0  22.8  108.0  8.6  0.576  14.9  3.6  0.715
# Cheick Diallo  -3.1  -0.3  13.5  29.6  105.0  8.4  0.580  14.5  4.1  0.758
# JaMychal Green -1.5  -0.4  10.4  24.4  110.0  7.3  0.457  16.0  2.6  0.721
# Eric Moreland   2.6   5.8  12.2  27.6  101.0  4.1  0.541   7.6  0.7  0.379
# Noah Vonleh    -3.1   0.3  13.6  30.2  106.0  5.9  0.444  13.2  2.0  0.621
#
#                 FTA     G    GS      MP  OBPM  ORB  ORB%   ORtg   PER   PF  \
# Name
# Trevor Booker   3.9  68.0   7.0  1158.0  -1.0  4.9  11.1  114.0  14.9  5.0
# John Collins    5.1  74.0  26.0  1785.0  -0.2  4.8  11.0  117.0  18.3  5.9
# Cheick Diallo   5.4  52.0   0.0   581.0  -2.8  3.9   9.1  118.0  17.0  6.7
# JaMychal Green  3.6  55.0  54.0  1542.0  -1.2  4.8  10.8  108.0  14.0  5.0
# Eric Moreland   1.8  67.0   3.0   805.0  -3.1  5.0  10.9  111.0  13.9  7.2
# Noah Vonleh     3.3  54.0  16.0   875.0  -3.4  3.9   8.5  106.0  12.8  3.8
#
#                  PTS Pos  STL  STL%  TOV  TOV%   TRB  TRB%    TS%   Tm  USG%  \
# Name
# Trevor Booker   18.0  PF  1.2   1.2  2.5  13.3  13.4  14.9  0.557  TOT  16.6
# John Collins    21.3  PF  1.3   1.3  2.9  14.3  14.8  16.9  0.620  ATL  17.9
# Cheick Diallo   20.9  PF  0.9   0.9  2.3  12.0  17.3  19.7  0.619  NOP  17.4
# JaMychal Green  18.7  PF  1.0   1.0  2.5  12.4  15.2  17.4  0.530  MEM  17.8
# Eric Moreland    8.9  PF  1.9   1.9  2.6  23.8  17.2  19.1  0.531  DET   9.7
# Noah Vonleh     14.9  PF  1.1   1.1  1.7  10.7  17.5  19.2  0.509  TOT  14.5
#
#                 VORP  pf_cluster
# Name
# Trevor Booker    0.4           3
# John Collins     1.7           3
# Cheick Diallo   -0.2           3
# JaMychal Green   0.2           3
# Eric Moreland    0.9           3
# Noah Vonleh     -0.2           3

# %%
import plotly
plotly.tools.set_credentials_file(username='lawrencefsoto', api_key='Sg9BCjSVRVWL5jklUegz')
# plotting it based of the 3 strongest positive or negative correlation

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np

trace1 = go.Scatter3d(
    x=pf['3P'],
    y=pf['TRB'],
    z=pf['PER'],
    mode='markers',
    marker=dict(
        size=12,
        color=pf['pf_cluster'],                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)
data = [trace1]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-scatter-colorscale')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~lawrencefsoto/2.embed" height="525px" width="100%"></iframe>

# %%
pf.head()
# Out:
#                          2P    2P%   2PA   3P    3P%   3PA  AST  AST%   Age  \
# Name
# Quincy Acy              1.0  0.384   2.6  3.6  0.349  10.4  2.0   6.0  27.0
# Al-Farouq Aminu         2.5  0.432   5.8  3.0  0.369   8.1  2.0   5.8  27.0
# Ryan Anderson           2.2  0.539   4.0  3.7  0.386   9.7  1.7   5.1  29.0
# Giannis Antetokounmpo  12.6  0.554  22.8  0.8  0.307   2.5  6.5  23.7  23.0
# Carmelo Anthony         6.0  0.437  13.8  3.4  0.357   9.4  2.0   6.5  33.0
#
#                        BLK  BLK%  BPM  DBPM   DRB  DRB%   DRtg    FG    FG%  \
# Name
# Quincy Acy             1.0   1.6 -2.2  -0.2   7.8  17.0  110.0   4.6  0.356
# Al-Farouq Aminu        1.0   1.6  1.1   1.9  10.3  22.3  104.0   5.5  0.395
# Ryan Anderson          0.6   1.0  0.2  -0.8   6.8  15.4  109.0   5.9  0.431
# Giannis Antetokounmpo  1.9   3.3  5.8   1.9  10.8  25.3  106.0  13.4  0.529
# Carmelo Anthony        1.0   1.8 -3.8  -1.9   7.7  17.7  109.0   9.4  0.404
#
#                         FGA   FT    FT%   FTA     G    GS      MP  OBPM  ORB  \
# Name
# Quincy Acy             13.0  1.8  0.817   2.1  70.0   8.0  1359.0  -2.0  1.4
# Al-Farouq Aminu        14.0  1.4  0.738   1.9  69.0  67.0  2072.0  -0.8  2.3
# Ryan Anderson          13.7  2.1  0.774   2.7  66.0  50.0  1725.0   1.0  2.7
# Giannis Antetokounmpo  25.4  8.8  0.760  11.6  75.0  75.0  2756.0   3.9  2.8
# Carmelo Anthony        23.2  2.9  0.767   3.8  78.0  78.0  2501.0  -1.9  1.3
#
#                        ORB%   ORtg   PER   PF   PTS Pos  STL  STL%  TOV  TOV%  \
# Name
# Quincy Acy              3.1   99.0   8.2  5.3  14.7  PF  1.2   1.2  2.1  13.3
# Al-Farouq Aminu         5.2  105.0  12.0  3.3  15.5  PF  1.9   1.9  1.9  11.3
# Ryan Anderson           6.2  121.0  12.6  3.6  17.6  PF  0.7   0.7  1.2   7.5
# Giannis Antetokounmpo   6.7  116.0  27.3  4.2  36.4  PF  2.0   2.0  4.0  11.7
# Carmelo Anthony         2.9  104.0  12.7  3.9  25.0  PF  0.9   0.9  2.0   7.3
#
#                         TRB  TRB%    TS%   Tm  USG%  VORP  pf_cluster
# Name
# Quincy Acy              9.2  10.0  0.525  BRK  14.4  -0.1           0
# Al-Farouq Aminu        12.6  13.8  0.522  POR  14.8   1.6           2
# Ryan Anderson           9.4  10.8  0.592  HOU  14.4   1.0           2
# Giannis Antetokounmpo  13.6  16.0  0.598  MIL  31.2   5.4           4
# Carmelo Anthony         9.0  10.0  0.503  OKC  23.2  -1.1           1

# %%
from sklearn.externals import joblib

# %%
joblib.dump(ss, './pf_scaler.pk1')
# Out:
# ['./pf_scaler.pk1']

# %%
joblib.dump(pfk, './pf_kmeans.pk1')
# Out:
# ['./pf_kmeans.pk1']

# %%
pf.to_csv('./pf_cluster_17_18')
