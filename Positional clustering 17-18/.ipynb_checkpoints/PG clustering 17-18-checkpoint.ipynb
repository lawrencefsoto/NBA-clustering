# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import re

# %%
df = pd.read_csv('../clean_season_17_18')

# %%
df.shape
# Out:
# (372, 44)

# %%
df.shape
# Out:
# (372, 44)

# %%
df =df[df['G']>=40]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 371
# Data columns (total 44 columns):
# Name    334 non-null object
# 2P      334 non-null float64
# 2P%     334 non-null float64
# 2PA     334 non-null float64
# 3P      334 non-null float64
# 3P%     334 non-null float64
# 3PA     334 non-null float64
# AST     334 non-null float64
# Age     334 non-null float64
# BLK     334 non-null float64
# DRB     334 non-null float64
# DRtg    334 non-null float64
# FG      334 non-null float64
# FG%     334 non-null float64
# FGA     334 non-null float64
# FT      334 non-null float64
# FT%     334 non-null float64
# FTA     334 non-null float64
# G       334 non-null float64
# GS      334 non-null float64
# MP      334 non-null float64
# ORB     334 non-null float64
# ORtg    334 non-null float64
# PF      334 non-null float64
# PTS     334 non-null float64
# Pos     334 non-null object
# STL     334 non-null float64
# TOV     334 non-null float64
# ...

# %%
df.set_index('Name', inplace=True)

# %%
pg = df[df['Pos']=='PG']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from collections import Counter

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 700) # want to see more rows and columns

# %%
ss = StandardScaler()

# %%
X = pg.drop(columns=['G','GS','MP','Age','Pos','Tm']) ## took out columns that don't matter to the model

# %%
pg_scaled = ss.fit_transform(X)

# %%
## looking best cluster with inertia

# %%
cluster_range = range( 1, 6 )
cluster_errors = []

for num_clusters in cluster_range:
    clusters = KMeans(num_clusters)
    clusters.fit(pg_scaled)
    cluster_errors.append(clusters.inertia_)

clusters_df = pd.DataFrame({ "num_clusters":cluster_range, "cluster_errors": cluster_errors })

plt.figure(figsize=(8,4))
plt.plot( clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" );

# %%
# going to go with 3 clusters for inertia going to check silhoutte

# %%
from sklearn import cluster, metrics, datasets

# %%
import seaborn as sns

# %%
def kmeans(reduced_data, n_clusters):
    """
    performs kmeans clustering and returns labels, centroids, inertia, and silhouette score
    """
    kmeans = cluster.KMeans(n_clusters=n_clusters, random_state=42)
    kmeans = kmeans.fit(reduced_data)
    labels = kmeans.labels_
    centroids = kmeans.cluster_centers_
    inertia = kmeans.inertia_
    sil_score = metrics.silhouette_score(reduced_data, kmeans.labels_, metric='euclidean')

    data_dictionary = {
        "labels": labels,
        "centroids": centroids,
        "inertia" : inertia,
        "silhouette_score": sil_score
    }

    return data_dictionary

# %%
kmeans(pg_scaled,3)
# Out:
# {'labels': array([1, 0, 2, 2, 1, 1, 1, 1, 1, 2, 1, 1, 2, 1, 1, 1, 2, 1, 1, 1, 1, 1,
#         1, 1, 2, 1, 2, 1, 1, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 0, 1, 1, 1, 1,
#         1, 1, 2, 1, 1, 1, 1, 2, 2, 0, 1, 1, 1, 1, 1, 1, 1, 2, 2, 0, 1, 1],
#        dtype=int32),
#  'centroids': array([[ 1.13051473,  0.13345452,  1.0886183 , -0.92011511, -1.56147897,
#          -0.84826385,  0.92329162,  1.2972767 ,  2.83874651, -1.94573067,
#           0.51751586,  0.42285241,  0.38884476,  0.06395147, -2.02653936,
#           0.53431696,  2.90207106, -0.37787035, -0.1758373 ,  0.18898982,
#           1.15733098,  1.32577505,  3.01553761,  0.97588865,  1.29999696,
#           1.31613761,  2.5886891 ,  2.81852972,  0.18087609,  2.86708048,
#           0.76398891,  1.15733098,  0.86110277,  2.99965756, -0.58035277,
#           0.53538538,  1.63115379],
#         [-0.32982959, -0.18893514, -0.28883801, -0.2408703 ,  0.02235856,
#          -0.25324569, -0.25062152, -0.10516872, -0.29456105,  0.19328837,
# ...

# %%
def find_best_cluster(data,a,b):
    """
    plots and finds the best silhouette score for range(a,b)
    """
    scores = []
    for i in range(a,b):
        i_clusters = kmeans(data, i)
        sil_score_i = i_clusters['silhouette_score']
        scores.append(sil_score_i)

    sns.set_context('poster', font_scale=1)
    plt.plot(range(a,b), scores)
    plt.title("""Measuring Silhouette Score to Find Best Cluster""")
    print ("best silhouette score:", np.max(scores))

# %%
find_best_cluster(pg_scaled,2,7)
# Out:
# best silhouette score: 0.2411062943840017

# %%
# from silhoutte score it seems that 3 is still best cluster for PG

# %%
pgk= KMeans(n_clusters=3, random_state=42)
pgk.fit(pg_scaled)
pg['pg_cluster'] = pgk.labels_
Counter(pgk.labels_)
# Out:
# /Users/lawrencefrancosoto/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Counter({1: 48, 0: 4, 2: 14})

# %%
pg[pg['pg_cluster']==2]
# Out:
#                     2P    2P%   2PA   3P    3P%   3PA   AST   Age  BLK  DRB  \
# Name
# J.J. Barea         5.9  0.499  11.8  3.6  0.367   9.8  13.6  33.0  0.1  5.8
# Eric Bledsoe       7.4  0.545  13.5  2.7  0.347   7.7   7.9  28.0  0.9  5.0
# Stephen Curry      6.4  0.595  10.7  6.3  0.423  14.8   9.2  29.0  0.2  6.6
# Goran Dragic       7.9  0.481  16.4  2.3  0.370   6.3   7.6  31.0  0.3  5.3
# Tyreke Evans       7.9  0.482  16.5  3.6  0.399   9.0   8.5  28.0  0.5  7.0
# Kyrie Irving       9.5  0.541  17.6  4.3  0.408  10.5   7.9  25.0  0.4  5.0
# Reggie Jackson     8.1  0.475  16.9  2.2  0.308   7.0   9.9  27.0  0.2  4.0
# Damian Lillard     7.3  0.501  14.6  4.2  0.361  11.7   9.0  27.0  0.5  4.9
# Kyle Lowry         3.2  0.474   6.8  4.7  0.399  11.7  10.5  31.0  0.4  7.2
# Chris Paul         5.9  0.532  11.2  3.8  0.380  10.1  12.2  32.0  0.4  7.4
# D'Angelo Russell   7.4  0.477  15.5  3.5  0.324  10.9   9.8  21.0  0.7  6.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, Alex Abrines to Ivica Zubac
# Data columns (total 43 columns):
# 2P      334 non-null float64
# 2P%     334 non-null float64
# 2PA     334 non-null float64
# 3P      334 non-null float64
# 3P%     334 non-null float64
# 3PA     334 non-null float64
# AST     334 non-null float64
# Age     334 non-null float64
# BLK     334 non-null float64
# DRB     334 non-null float64
# DRtg    334 non-null float64
# FG      334 non-null float64
# FG%     334 non-null float64
# FGA     334 non-null float64
# FT      334 non-null float64
# FT%     334 non-null float64
# FTA     334 non-null float64
# G       334 non-null float64
# GS      334 non-null float64
# MP      334 non-null float64
# ORB     334 non-null float64
# ORtg    334 non-null float64
# PF      334 non-null float64
# PTS     334 non-null float64
# Pos     334 non-null object
# STL     334 non-null float64
# TOV     334 non-null float64
# TRB     334 non-null float64
# ...

# %%
import seaborn as sns

# %%
corr=pg.corr()

corr = corr.sort_values('pg_cluster',ascending=False)

plt.figure(figsize=(9,10))
sns.barplot(corr.pg_cluster[1:], corr.index[1:], color='b')
plt.show()

# %%
pg.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA   AST   Age  BLK  DRB  \
# Name
# D.J. Augustin    3.6  0.485   7.5  3.2  0.419  7.6   8.0  30.0  0.0  3.6
# Lonzo Ball       3.0  0.420   7.2  2.4  0.305  7.9  10.1  20.0  1.2  7.8
# J.J. Barea       5.9  0.499  11.8  3.6  0.367  9.8  13.6  33.0  0.1  5.8
# Eric Bledsoe     7.4  0.545  13.5  2.7  0.347  7.7   7.9  28.0  0.9  5.0
# Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6   5.3  25.0  0.5  4.6
#
#                   DRtg    FG    FG%   FGA   FT    FT%  FTA     G    GS  \
# Name
# D.J. Augustin    113.0   6.8  0.452  15.0  4.6  0.868  5.3  75.0  36.0
# Lonzo Ball       106.0   5.5  0.360  15.2  0.9  0.451  1.9  52.0  50.0
# J.J. Barea       112.0   9.5  0.439  21.6  2.5  0.784  3.2  69.0  10.0
# Eric Bledsoe     108.0  10.0  0.473  21.2  5.4  0.795  6.8  74.0  74.0
# Malcolm Brogdon  113.0   8.5  0.485  17.5  2.6  0.882  3.0  48.0  20.0
#
#                      MP  ORB   ORtg   PF   PTS Pos  STL  TOV  TRB   Tm  AST%  \
# ...

# %%
pg[pg['pg_cluster']==2]['TRB'].mean()
# Out:
# 6.492857142857145

# %%
pg[pg['pg_cluster']==0]['TRB'].mean()
# Out:
# 12.075

# %%
pg[pg['pg_cluster']==1]['TRB'].mean()
# Out:
# 5.672916666666667

# %%
# pg cluster 
# 0 PG ast, block, rb, low FT%
# 1 traditonal PG
# 2 scoring PG - 3's, ast, FT%

# %%
pg.head()
# Out:
#                   2P    2P%   2PA   3P    3P%  3PA   AST   Age  BLK  DRB  \
# Name
# D.J. Augustin    3.6  0.485   7.5  3.2  0.419  7.6   8.0  30.0  0.0  3.6
# Lonzo Ball       3.0  0.420   7.2  2.4  0.305  7.9  10.1  20.0  1.2  7.8
# J.J. Barea       5.9  0.499  11.8  3.6  0.367  9.8  13.6  33.0  0.1  5.8
# Eric Bledsoe     7.4  0.545  13.5  2.7  0.347  7.7   7.9  28.0  0.9  5.0
# Malcolm Brogdon  6.3  0.532  11.9  2.2  0.385  5.6   5.3  25.0  0.5  4.6
#
#                   DRtg    FG    FG%   FGA   FT    FT%  FTA     G    GS  \
# Name
# D.J. Augustin    113.0   6.8  0.452  15.0  4.6  0.868  5.3  75.0  36.0
# Lonzo Ball       106.0   5.5  0.360  15.2  0.9  0.451  1.9  52.0  50.0
# J.J. Barea       112.0   9.5  0.439  21.6  2.5  0.784  3.2  69.0  10.0
# Eric Bledsoe     108.0  10.0  0.473  21.2  5.4  0.795  6.8  74.0  74.0
# Malcolm Brogdon  113.0   8.5  0.485  17.5  2.6  0.882  3.0  48.0  20.0
#
#                      MP  ORB   ORtg   PF   PTS Pos  STL  TOV  TRB   Tm  AST%  \
# ...

# %%
## checking the distance from each cluster make sure they are seperate enough

# %%
from scipy.spatial import distance

# %%
lonzo = pd.DataFrame(pg.loc['Lonzo Ball'][:43]).T.drop(columns=['Age','G','GS','MP','Pos','Tm'])

# %%
lonzo_scaled=ss.transform(lonzo)
pgk.predict(lonzo_scaled)
# Out:
# array([0], dtype=int32)

# %%
for i in range(0,3):
    print('dist between evan_scaled and cluster', i, ':', distance.euclidean(lonzo_scaled, pgk.cluster_centers_[i]))
# Out:
# dist between evan_scaled and cluster 0 : 7.580402359781435
# dist between evan_scaled and cluster 1 : 8.734419043164749
# dist between evan_scaled and cluster 2 : 11.09412064862857

# %%
barea = pd.DataFrame(pg.loc['J.J. Barea'][:43]).T.drop(columns=['Age','G','GS','MP','Pos','Tm'])

# %%
barea_scaled=ss.transform(barea)
pgk.predict(barea_scaled)
# Out:
# array([2], dtype=int32)

# %%
for i in range(0,3):
    print('dist between evan_scaled and cluster', i, ':', distance.euclidean(barea_scaled, pgk.cluster_centers_[i]))
# Out:
# dist between evan_scaled and cluster 0 : 11.806101183978697
# dist between evan_scaled and cluster 1 : 6.4761506577197725
# dist between evan_scaled and cluster 2 : 5.208979812435929

# %%
## performed check PG is good

# %%
pg['pg_cluster'].unique()
# Out:
# array([1, 0, 2])

# %%
corr.pg_cluster[4:]
# Out:
# OBPM    0.534391
# FGA     0.519216
# USG%    0.507104
# FG      0.506748
# FT      0.486275
# FT%     0.464748
# PER     0.457537
# FTA     0.396093
# TS%     0.375110
# 3P%     0.346178
# ORtg    0.311199
# BPM     0.281442
# AST%    0.257383
# 2P%     0.242574
# Age     0.238918
# 2P      0.205782
# VORP    0.203509
# DRtg    0.190633
# GS      0.186418
# 2PA     0.156292
# TOV     0.143811
# AST     0.140777
# FG%     0.101094
# MP      0.086543
# BLK    -0.161593
# BLK%   -0.182093
# G      -0.200109
# STL    -0.230782
# STL%   -0.230782
# PF     -0.243490
# DRB%   -0.258614
# DRB    -0.259848
# TOV%   -0.297237
# TRB%   -0.302328
# TRB    -0.309143
# ORB%   -0.365057
# ORB    -0.369236
# DBPM   -0.418041
# Name: pg_cluster, dtype: float64

# %%
pgcorr=pg[pg['pg_cluster']==0].corr()

# %%
corr=pg.corr()

corr = corr.sort_values('pg_cluster',ascending=False)

plt.figure(figsize=(9,10))
sns.barplot(corr.pg_cluster[1:], corr.index[1:], color='b')
plt.show()

# %%
pg.groupby(['pg_cluster']).mean().plot(kind='barh', figsize=(10,10))

# %%
pg_test=pg.drop(columns=['Age', 'MP','G','GS'])

# %%
pg_2p= pg[['VORP','pg_cluster']]

# %%
pg_2p.groupby(['pg_cluster']).mean().plot(kind='barh', figsize=(8,8))

# %%
# pg cluster 
# 0 new-meta pg- ast, block, trb, low FT%, STL, highest TOV, low 3p%
# 1 traditonal PG lower ast, pf, lowest USG%
# 2 scoring PG - 3's, ast, FT%, PTS, lowest STL, highest USG%

## VORP is value over replacement player 0 and 2 are highest then 1 is replaceable

# %%
pg.groupby(['pg_cluster']).mean()

# %%
pg_test.groupby(['pg_cluster']).mean().plot(kind='barh', figsize=(10,10))

# %%
pg[pg['pg_cluster']==0]

# %%
pg.head()

# %%
pg.head()

# %%
##pg.to_csv('./pg_cluster_17_18')
